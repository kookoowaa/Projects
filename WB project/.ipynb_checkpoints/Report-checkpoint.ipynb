# %% [markdown]
# # Is Soju really cannibalizing Beer?
# (by Park, Pablo Chanwoo)

# %% [markdown]
# ### EXECUTIVE SUMMARY
# >- ff

# %% [markdown]
# ### Project description
#
# 1. WB has come up with a hypothesis; **"Soju is cannibalizing beer sales".**
# 2. Approve or reject the hypothesis using transaction data. (daily summary, 147 locations, for 6 months)

# %% [markdown]
# ### Project approach
#
# I would like to first define the hypothesis fisrt. By stating that "product A is being cannibalized", I can presume that **1) the sales volume in proportion should be decreasing, 2) product A and the one that is canibalizing should be moving towards negative correlation.** In order to test the hypothesis according to the definitions of cannibalization I understand, studying regression coefficients may seem like a rational approach, and I may also consider studying importance of features in determining demands for beer, while simple EDA may be enough to test hypothesis. On top of it, I may consider clustering data by types of bar, season, or any other features that reflects own characteristics of cluster itself, in order to develop this project further.

# %% [markdown]
# ### Python libraries for the project
#
# The following libraries will be used for this project:
# - **pandas/numpy**: for data manipulation and basic statistical study
# - **seaborn/matplotlib**: for graphic visualization of findings
# - **sklearn**: for descriptive analysis
# - **re**: for filtering via column names

# %%
import pandas as pd

import seaborn as sns

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import re

import sklearn

# %pylab inline
pylab.rcParams['figure.figsize'] = (16, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 1. EDA

# %% [markdown]
# > -

# %% [markdown]
# ### Data exploration
#
# - As given in instruction, the data is from 147 outlets over 6-month period.
# - There are only 3 segments for bars `['Food,Spirits', 'Beer,Food', 'Food']`.
# - There are zeroes, but no missing value.
# - The data mainly consists of volume(units), revenue, count of oders.
# - `Avg. Check Size`(Total Revenue / number of Check) and `Soju Price`(Soju Revenue / Soju Units) seem like derived variables

# %%
data = pd.read_excel("c:/testData.xlsx")
data.shape
# Out:
# (16635, 22)

# %%
data.head()
# Out:
#   Bar ID       Date Bar Segmentation  Beer Draught Volume (L)  \
# 0  Bar 1 2017-07-01     Food,Spirits                      9.3
# 1  Bar 1 2017-07-02     Food,Spirits                     21.3
# 2  Bar 1 2017-07-03     Food,Spirits                      9.3
# 3  Bar 1 2017-07-04     Food,Spirits                     15.9
# 4  Bar 1 2017-07-05     Food,Spirits                      1.7
#
#    Beer Packaged Volume (L)  Total Volume (L)  Total Revenue   Beer Revenue  \
# 0                      6.16             15.46          887100        124500
# 1                      2.50             23.80          745800        167500
# 2                      2.50             11.80          575100         87000
# 3                      7.50             23.40          553500        178000
# 4                      8.00              9.70          256600         84000
#
#    Beer Units  Spirits Revenue     ...      Non Alcoholic Revenue  \
# 0          22           278000     ...                      23500
# 1          16           256000     ...                      24000
# 2          12           237000     ...                      10000
# 3          26           146000     ...                       4000
# 4          17            80500     ...                          0
#
#    Wine Revenue  Soju Revenue  Soju Units  # Beer Orders  \
# 0             0         54000          12             14
# 1             0         18000           4              7
# 2             0         27000           5              7
# 3             0         27000           5             12
# 4             0          4500           1              7
#
#    # Beer & Food Orders  # Soju & Beer Orders  # Soju & Food Orders  \
# 0                    14                     1                     7
# 1                     7                     1                     2
# 2                     7                     2                     4
# 3                    12                     2                     4
# 4                     7                     1                     1
#
#    Avg. Check Size  Soju Price
# 0     26881.818182      4500.0
# 1     46612.500000      4500.0
# 2     26140.909091      5625.0
# 3     34593.750000      5625.0
# 4     28511.111111      4500.0
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16635 entries, 0 to 16634
# Data columns (total 22 columns):
# Bar ID                      16635 non-null object
# Date                        16635 non-null datetime64[ns]
# Bar Segmentation            16635 non-null object
# Beer Draught Volume (L)     16635 non-null float64
# Beer Packaged Volume (L)    16635 non-null float64
# Total Volume (L)            16635 non-null float64
# Total Revenue               16635 non-null int64
# Beer Revenue                16635 non-null int64
# Beer Units                  16635 non-null int64
# Spirits Revenue             16635 non-null int64
# Spirits Units               16635 non-null int64
# Food Revenue                16635 non-null int64
# Non Alcoholic Revenue       16635 non-null int64
# Wine Revenue                16635 non-null int64
# Soju Revenue                16635 non-null int64
# Soju Units                  16635 non-null int64
# # Beer Orders               16635 non-null int64
# # Beer & Food Orders        16635 non-null int64
# # Soju & Beer Orders        16635 non-null int64
# # Soju & Food Orders        16635 non-null int64
# Avg. Check Size             16635 non-null float64
# Soju Price                  16635 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(14), object(2)
# memory usage: 2.8+ MB

# %%
pd.options.display.max_columns = None
# display all DataFrame columns to check with my own eyes

data.columns = ['barId', 'date', 'segment', 'draughtV', 'packagedV',
                'totalV', 'totalR', 'beerR', 'beerU', 'spiritsR',
                'spiritsU', 'foodR', 'nonAlcoholR', 'wineR', 'sojuR', 
                'sojuU', 'beerO', 'beerFoodO', 'sojuBeerO', 'sojuFoodO',
               'avgCheck', 'sojuP']
# change column names to index easily

# %%
data.head()
# Out:
#    barId       date       segment  draughtV  packagedV  totalV  totalR  \
# 0  Bar 1 2017-07-01  Food,Spirits       9.3       6.16   15.46  887100
# 1  Bar 1 2017-07-02  Food,Spirits      21.3       2.50   23.80  745800
# 2  Bar 1 2017-07-03  Food,Spirits       9.3       2.50   11.80  575100
# 3  Bar 1 2017-07-04  Food,Spirits      15.9       7.50   23.40  553500
# 4  Bar 1 2017-07-05  Food,Spirits       1.7       8.00    9.70  256600
#
#     beerR  beerU  spiritsR  spiritsU   foodR  nonAlcoholR  wineR  sojuR  \
# 0  124500     22    278000        68  461100        23500      0  54000
# 1  167500     16    256000        63  298300        24000      0  18000
# 2   87000     12    237000        57  234100        10000      0  27000
# 3  178000     26    146000        35  222500         4000      0  27000
# 4   84000     17     80500        20   92100            0      0   4500
#
#    sojuU  beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck   sojuP
# 0     12     14         14          1          7  26881.818182  4500.0
# 1      4      7          7          1          2  46612.500000  4500.0
# 2      5      7          7          2          4  26140.909091  5625.0
# 3      5     12         12          2          4  34593.750000  5625.0
# 4      1      7          7          1          1  28511.111111  4500.0

# %%
data.tail()
# Out:
#          barId       date segment  draughtV  packagedV  totalV   totalR  \
# 16630  Bar 147 2017-12-27    Food      28.7       0.66   29.36  1204538
# 16631  Bar 147 2017-12-28    Food      43.8       1.65   45.45  1403450
# 16632  Bar 147 2017-12-29    Food      50.9       2.64   53.54  1688716
# 16633  Bar 147 2017-12-30    Food      44.9       1.98   46.88  1577712
# 16634  Bar 147 2017-12-31    Food      37.2       7.92   45.12  2478161
#
#         beerR  beerU  spiritsR  spiritsU    foodR  nonAlcoholR  wineR  sojuR  \
# 16630  187728     54     83635        23   911358        21817      0      0
# 16631  291820     77     58180        16  1035270        18180      0      0
# 16632  352273    103     80000        22  1229627        26816      0      0
# 16633  309546     91     36360        10  1206445        25361      0      0
# 16634  318639     89     54545        15  2043801        61176      0      0
#
#        sojuU  beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck  sojuP
# 16630      0     15         15          0          0  19119.650794    0.0
# 16631      0     22         22          0          0  23007.377049    0.0
# 16632      0     17         17          0          0  19867.247059    0.0
# 16633      0     20         19          0          0  19008.578313    0.0
# 16634      0     28         27          0          0  17329.797203    0.0

# %%
data.apply(lambda x: len(x.unique()))
# there are 3 bar segments only out of 147 bars
# Out:
# barId            147
# date             184
# segment            3
# draughtV        4687
# packagedV       2416
# totalV          7489
# totalR         10683
# beerR           5395
# beerU            474
# spiritsR        2997
# spiritsU         377
# foodR           8772
# nonAlcoholR     1738
# wineR            353
# sojuR           1509
# sojuU            219
# beerO            198
# beerFoodO        188
# sojuBeerO         56
# sojuFoodO         89
# avgCheck       14061
# sojuP            252
# dtype: int64

# %%
data.segment.unique()
# Out:
# array(['Food,Spirits', 'Beer,Food', 'Food'], dtype=object)

# %%
data.isna().sum()
# there are no missing values
# Out:
# barId          0
# date           0
# segment        0
# draughtV       0
# packagedV      0
# totalV         0
# totalR         0
# beerR          0
# beerU          0
# spiritsR       0
# spiritsU       0
# foodR          0
# nonAlcoholR    0
# wineR          0
# sojuR          0
# sojuU          0
# beerO          0
# beerFoodO      0
# sojuBeerO      0
# sojuFoodO      0
# avgCheck       0
# sojuP          0
# dtype: int64

# %% [markdown]
# ### Descriptive Analysis
#
# >- Over time, "Beer Units" sold are in a downward trend, but the sample size is too small to be considered stable during the early stage of observation.
# - "Soju Units" do not seem to demonstrate upward demands.
# - Looking at the correlation too, "Beer Units" and "Soju Units" show more and more positive relationship over time.
# - The variables are in right-skewed distribution, and needs normalization before regression.
# - The bars do not share similar characteristics (some may), and clustering/grouping may reveal unexplained insights.
#
#
# *In most case, used Units instead of Revenue to explain demand, as Revenu is consequence to demands and is effected by many other factors (I.e. price, promotion)*

# %%
dataLong = data.melt(['barId', 'date', 'segment'])
# convert data into long format to easily visualize
sns.lineplot(data=dataLong[dataLong['variable'].isin(['sojuU', 'beerU', 'spiritsU'])], x = 'date', y='value', hue='variable')
plt.title("Sales trend by the type of beverage")
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-35-0fb7549ffc4b> in <module>
#       1 dataLong = data.melt(['barId', 'date', 'segment'])
#       2 # convert data into long format to easily visualize
# ----> 3 sns.lineplot(data=dataLong[dataLong['variable'].isin(['sojuU', 'beerU', 'spiritsU'])], x = 'date', y='value', hue='variable')
#       4 plt.title("Sales trend by the type of beverage")
#
# C:\Programming\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# C:\Programming\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
#     776             else:
#     777                 y_ci = None
#
# C:\Programming\Anaconda3\lib\site-packages\seaborn\relational.py in aggregate(self, vals, grouper, units)
#     703         # Group and get the aggregation estimate
#     704         grouped = vals.groupby(grouper, sort=self.sort)
# --> 705         est = grouped.agg(func)
#     706
#     707         # Exit early if we don't want a confidence interval
#
# C:\Programming\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3477         _level = kwargs.pop('_level', None)
#    3478         if isinstance(func_or_funcs, compat.string_types):
# -> 3479             return getattr(self, func_or_funcs)(*args, **kwargs)
#    3480
#    3481         if isinstance(func_or_funcs, collections.Iterable):
#
# C:\Programming\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# C:\Programming\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1054
#    1055         if len(output) == 0:
# -> 1056             raise DataError('No numeric types to aggregate')
#    1057
#    1058         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %% [markdown]
# - It seems like there is a downward sales trend for beer, while soju and spirits remain constant.
# - The variance of sales data is getting smaller towards the end of year. (It should be on the other way around in general cases)

# %%
tmp = data[['date', 'beerU']]
tmp['month'] = [d.month_name() for d in tmp['date']]
tmpA = tmp.groupby('month').mean()
tmpB = tmp.groupby('month').std()
tmp = pd.merge(tmpA, tmpB, left_index=True, right_index=True)
tmp.columns = ['mean', 'std']
tmp = tmp.iloc[[2,0,5,4,3,1],:]
tmp
# Out:
# C:\Programming\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  mean         std
# month
# July       109.949657  127.784307
# August      80.825762   95.144610
# September   70.827905   75.716210
# October     65.074388   71.730805
# November    54.495392   58.723028
# December    58.706543   62.453384

# %%
data.groupby('date', as_index=False)['barId'].count().plot(x='date', y = 'barId')
plt.title("The number of observations by date")
# Out:
# Text(0.5, 1.0, 'The number of observations by date')

# %%
data.groupby('date', as_index=False)['barId'].count().sort_values('barId').head()
# Out:
#          date  barId
# 8  2017-07-09     23
# 1  2017-07-02     24
# 16 2017-07-17     24
# 15 2017-07-16     24
# 0  2017-07-01     25

# %% [markdown]
# - The high variance in the early date of data may have been effected by few observations.
# - I can also note that the observations are not evenly available, and this may lead to biased result.(only 23 observations available for the 9th July)

# %%
data.groupby('barId', as_index=False)['date'].count().sort_values('date', ascending=False).head(10)
# Out:
#       barId  date
# 70    Bar 3   184
# 59    Bar 2   184
# 55   Bar 16   181
# 76   Bar 35   181
# 54   Bar 15   180
# 1    Bar 10   180
# 114   Bar 7   180
# 34   Bar 13   180
# 92    Bar 5   180
# 58   Bar 19   179

# %%
tmp = dataLong[dataLong['variable'].isin(['sojuU', 'beerU', 'spiritsU'])]
tmp = tmp[tmp.barId.isin(['Bar 3', 'Bar 2'])]
sns.FacetGrid(data=tmp, row = 'barId', hue = 'variable', height=8, aspect = 2, margin_titles=True).map(sns.lineplot,'date', 'value')
plt.legend()
plt.suptitle("The sales of beverages in Bars with full observations")
# Out:
# Text(0.5, 0.98, 'The sales of beverages in Bars with full observations')

# %% [markdown]
# - There are two(2) bars with full data over the observed period.
# - Both bars do not seem to sell soju. (unless spirits contains soju-likes.)
# - It is difficult to state that the sales trend, for any kinds, is increasing/decreasing.
# ___

# %%
sns.heatmap(data.corr(), annot=True, vmin=-1, vmax=1)
plt.title('Correlation matrix for all variables')
# Out:
# Text(0.5, 1.0, 'Correlation matrix for all variables')

# %% [markdown]
# - Obviously volume/units are highly correlated against revenue
# - To test cannibalization, units refelect demands while revenue may mislead demands (i.e. promotion in beers may end up with more units sold, but less in revenue)
# - Should be careful with the variable selection on regression

# %%
reCompile = re.compile('R$')
tmp = [not bool(reCompile.search(column)) for column in data.columns]

# %%
sns.heatmap(data.loc[:,tmp].corr(), vmin=-1, vmax=1, annot=True)
plt.title('correlation matrix without revenue variables')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-3e836a0eb288> in <module>
# ----> 1 sns.heatmap(data.loc[:,tmp].corr(), vmin=-1, vmax=1, annot=True)
#       2 plt.title('correlation matrix without revenue variables')
#
# C:\Programming\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# C:\Programming\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# C:\Programming\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1897
#    1898                 if hasattr(key, 'ndim') and key.ndim > 1:
# -> 1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
#    1901                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
data[['beerO', 'beerFoodO']].head()
# Out:
#    beerO  beerFoodO
# 0     14         14
# 1      7          7
# 2      7          7
# 3     12         12
# 4      7          7

# %% [markdown]
# - My interests is largely with variable "Beer Units", and from the correlation matrix it seems there is no relationship betwen "Soju Units" and "Beer Units". (0.022)
# - On the other hand, what had caught my attention from correlation table are:
# > 1. "Beer Draught Volume(L)" is more determinantal to "Total Volume(L)" of beer from given sample bars.
# > 2. "# Beer Orders" and "# Beer & Food Orders" are highly correlated, and also very much correlated with "Beer Units": They almost never orders beer withou food.

# %%
data['month'] = [day.month_name() for day in data.date]
# added month as a categorical feature

# %%
g = sns.FacetGrid(data[['beerU', 'spiritsU', 'sojuU', 'month']], col = 'month', height=6, col_wrap=3)
g.map_dataframe(lambda data, color: sns.heatmap(data.corr(), vmin=-1, vmax=1, annot=True, square=True, cbar=False))
plt.suptitle('The difference in correlation from July to December', y = 1.05)
# Out:
# Text(0.5, 1.05, 'The difference in correlation from July to December')

# %% [markdown]
# - Comparing correlation for sales volume in July and December, I see that both Soju and Spirits are more positively correlated in December than in July.
# - In fact, the correlation is consistantly moving towards positive between Soju and Beer.
# ___

# %%
g = sns.FacetGrid(data=dataLong, col = 'variable', col_wrap = 4, sharey=False, sharex=False)
g.map(sns.distplot, 'value')
plt.suptitle("The distribution of values in variables", y = 1.05)
# Out:
# Text(0.5, 1.05, 'The distribution of values in variables')

# %% [markdown]
# - All the variables are right-skewed, and the variables may need to be normalized before fitted to the model.

# %%
log(data.sojuU+e**(-5))
# Out:
# C:\Programming\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# 0        2.485468
# 1        1.387977
# 2        1.610785
# 3        1.610785
# 4        0.006715
# 5        1.387977
# 6        1.946872
# 7        0.006715
# 8        2.485468
# 9        1.946872
# 10       0.696510
# 11       1.610785
# 12       1.387977
# 13       0.696510
# 14      -5.000000
# 15       0.696510
# 16       1.100856
# 17       1.610785
# 18       2.080283
# 19       1.610785
# 20       1.387977
# 21       0.696510
# 22       0.696510
# 23       0.696510
# 24       0.006715
# 25       2.080283
# 26       1.946872
# 27       1.946872
# 28       1.946872
# 29       1.100856
#            ...
# 16605   -5.000000
# 16606   -5.000000
# 16607   -5.000000
# 16608   -5.000000
# 16609   -5.000000
# 16610   -5.000000
# 16611   -5.000000
# 16612   -5.000000
# 16613   -5.000000
# 16614   -5.000000
# 16615   -5.000000
# 16616   -5.000000
# 16617   -5.000000
# 16618   -5.000000
# 16619   -5.000000
# 16620   -5.000000
# 16621   -5.000000
# 16622   -5.000000
# 16623   -5.000000
# 16624   -5.000000
# 16625   -5.000000
# 16626   -5.000000
# 16627   -5.000000
# 16628   -5.000000
# 16629   -5.000000
# 16630   -5.000000
# 16631   -5.000000
# 16632   -5.000000
# 16633   -5.000000
# 16634   -5.000000
# Name: sojuU, Length: 16635, dtype: float64

# %%
data.sojuU.unique()
# Out:
# array([ 12,   4,   5,   1,   7,   2,   0,   3,   8,  14,   9,  15,  10,
#         11,   6,  13,  16,  49,  91, 139,  21,  33, 105, 104,  41,  64,
#        118, 125,  47, 109,  86, 334, 400,  24, 219, 342, 318,  18,  94,
#        130,  68, 286, 360, 238, 140,  66, 116, 222, 304, 420,  27,  19,
#         23,  37,  22,  31,  26,  56,  32,  20,  17,  40,  29,  35,  34,
#         25,  59,  36,  43,  38,  42,  39,  57,  28,  52,  60,  54,  62,
#         48,  46,  30,  55,  69,  50,  44,  53,  45,  67,  65,  88,  81,
#        131, 115,  92,  79,  71,  72,  83,  77,  63,  82, 101,  73, 111,
#         70,  80,  98,  51,  78,  74, 122, 113, 151, 123, 119, 148, 124,
#         89, 121,  58,  84, 117,  93,  75,  90, 110, 106, 108, 128,  95,
#        192, 135, 152, 107, 142,  96, 216, 181,  87, 185, 102, 136, 157,
#        133, 156, 154, 176,  97, 190, 184, 182, 196,  99, 149, 144, 201,
#        163, 266, 202, 197, 274,  85,  76, 464, 230, 298, 177, 183, 146,
#        138, 194, 186, 134, 172, 161, 103, 199, 198, 242, 173, 207, 127,
#        203, 145,  61, 188, 209, 143, 225, 150, 261, 328, 100, 120, 237,
#         -1, 507, 427, 311, 273, 491, 461, 114, 155, 170, 169, 141, 147,
#        162, 153, 112, 171, 166, 208, 168, 132, 126, 129, 137], dtype=int64)

# %% [markdown]
# - There are impossible values in Soju Units (-1), which needs to be fixed.
# - Should I log-scale after pre-processing, it would return variables in distribution look similar to below for regression:

# %%
sns.distplot(log(data.sojuU+1+e**(-5)))
plt.title('approximate distribution of log(Soju Units)')
# Out:
# Text(0.5, 1.0, 'approximate distribution of log(Soju Units)')

# %% [markdown]
# ___

# %%
tmp = data.groupby('barId')[['beerU', 'spiritsU']].mean()
tmp['beerPct'] = tmp.apply(lambda x: round(x[0]/sum(x),2), axis=1)
tmp.beerPct.describe()
# Out:
# count    147.000000
# mean       0.697755
# std        0.203974
# min        0.240000
# 25%        0.590000
# 50%        0.780000
# 75%        0.840000
# max        1.010000
# Name: beerPct, dtype: float64

# %%
sns.boxplot(tmp.beerPct)
plt.title("The proportion of beer sold to beer+spirits")
# Out:
# Text(0.5, 1.0, 'The proportion of beer sold to beer+spirits')

# %%
tmp['spiritsPct'] = 1-tmp.beerPct
tmp = tmp.drop(['beerU', 'spiritsU'], axis=1)
tmp.plot(kind='bar', stacked=True)
plt.xticks(rotation=45, size = 6)
plt.title('The proportion of beer sold to beer+spirits by bar')
# Out:
# Text(0.5, 1.0, 'The proportion of beer sold to beer+spirits by bar')

# %%
tmp = data.groupby('barId')[['beerU', 'spiritsU']].mean()
tmp.plot(kind='bar', stacked=True)
plt.rc
plt.xticks(rotation=45, size = 6)
plt.title('The average units sold per bar')
# Out:
# Text(0.5, 1.0, 'The average units sold per bar')

# %%
sns.scatterplot(data=data.groupby('barId')[['beerU', 'spiritsU']].mean(), x = 'beerU', y = 'spiritsU')
plt.title('Distribution of bars by beer and spirits units sold')
# Out:
# Text(0.5, 1.0, 'Distribution of bars by beer and spirits units sold')

# %% [markdown]
# - From sample bars, beers are tend to be more frequently sought.
# - However, the proportion vary much by bars.
# - Clustering/grouping bars by characteristics may reveal different types of demands and explanation for cannibalization hypothesis for analysis.
# ___

# %% [markdown]
# ## 2. Data pre-process

# %% [markdown]
# - Dealing with zeros
# - Impossible values
# - Outliers
# - Preliminary variable selection / normalization

# %%
testData= data
testData.head()
# Out:
#    barId       date       segment  draughtV  packagedV  totalV  totalR  \
# 0  Bar 1 2017-07-01  Food,Spirits       9.3       6.16   15.46  887100
# 1  Bar 1 2017-07-02  Food,Spirits      21.3       2.50   23.80  745800
# 2  Bar 1 2017-07-03  Food,Spirits       9.3       2.50   11.80  575100
# 3  Bar 1 2017-07-04  Food,Spirits      15.9       7.50   23.40  553500
# 4  Bar 1 2017-07-05  Food,Spirits       1.7       8.00    9.70  256600
#
#     beerR  beerU  spiritsR  spiritsU   foodR  nonAlcoholR  wineR  sojuR  \
# 0  124500     22    278000        68  461100        23500      0  54000
# 1  167500     16    256000        63  298300        24000      0  18000
# 2   87000     12    237000        57  234100        10000      0  27000
# 3  178000     26    146000        35  222500         4000      0  27000
# 4   84000     17     80500        20   92100            0      0   4500
#
#    sojuU  beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck   sojuP month
# 0     12     14         14          1          7  26881.818182  4500.0  July
# 1      4      7          7          1          2  46612.500000  4500.0  July
# 2      5      7          7          2          4  26140.909091  5625.0  July
# 3      5     12         12          2          4  34593.750000  5625.0  July
# 4      1      7          7          1          1  28511.111111  4500.0  July

# %% [markdown]
# ### Dealing with zeros
#
# - The observation of zero values in units sold would imply two different cases
#     1. There is no market demand for the item on the day
#     2. They do not sell the item from the bar
# - The former reflect consumers' taste for the product.
# - The letter is option unavailable to the market, which should be interpreted as NA instead of zero.
# - Also for this project, the key variables are "Beer Units" and "Soju Units", and bars without items will be excluded for the analysis

# %%
tmp = testData.groupby('barId', as_index=False).sum().sort_values('sojuU')
tmp.head(15)
# Out:
#        barId  draughtV  packagedV     totalV     totalR      beerR   beerU  \
# 51   Bar 145    155.70    126.720    282.420   16508000    2696000     670
# 49   Bar 143    185.50    146.230    331.730   16386500    2981200     758
# 53   Bar 147   1325.10     90.750   1415.850   61162664   10026384    2547
# 25   Bar 121     70.00     21.120     91.120    8514882     699271     187
# 59     Bar 2  12779.22   5193.350  17972.570  981541700  173039900   26144
# 140   Bar 93    522.37    129.020    651.390   51407500   26429500    3931
# 63    Bar 23   2014.41    232.560   2246.970   93985355   20195544    3729
# 70     Bar 3  48206.85   3530.805  51737.655  814204267  443657900  102359
# 113   Bar 69   2314.20   1775.010   4089.210  149364000   32668500    6414
# 83    Bar 41   2664.75    614.460   3279.210   82502783   30744959    6397
# 107   Bar 63   2916.30   1459.190   4375.490  173327692   33733706    5853
# 36   Bar 131    260.80     22.130    282.930   10947900    2384500     548
# 93    Bar 50    212.97     83.490    296.460  149342497    5786990    1046
# 3    Bar 101    326.69    365.755    692.445  146410050   87937400   10703
# 106   Bar 62    556.70     68.160    624.860  135908500   39124000    3375
#
#       spiritsR  spiritsU      foodR  nonAlcoholR     wineR  sojuR  sojuU  \
# 51     3428000       718   10065000        96000         0      0      0
# 49     2706000       603    8862300       154000   1683000      0      0
# 53     2364713       607   47284946      1486621         0      0      0
# 25     2354177       597    5370163        91271         0      0      0
# 59   335194000     48312  446390000     21024000         0      0      0
# 140     987000       118   23015500       599500         0      0      0
# 63     4717350      1282   65371121      3480340         0      0      0
# 70    86078000     17540  272560267      8422000         0      0      0
# 113   53575000     13245   57454500      5666000         0      0      0
# 83    11715358      2317   38709926      1332540         0      0      0
# 107   47687862     10823   87651714      4254410         0      0      0
# 36      569500       142    7844400       149500         0      0      0
# 93       27728        -7  135709203      4708446   3195485      0      0
# 3      4291000       623   48831000      1310000         0      0      0
# 106    6755500       268   55867000      2178000  27506000      0      0
#
#      beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck  sojuP
# 51     197        188          0          0  2.113623e+06    0.0
# 49     223        215          0          0  2.400752e+06    0.0
# 53     758        726          0          0  9.208392e+05    0.0
# 25      65         64          0          0  1.377120e+06    0.0
# 59    8866       8768          0          0  1.135304e+07    0.0
# 140    965        759          0          0  4.914805e+06    0.0
# 63    1618       1588          0          0  6.857703e+06    0.0
# 70   29472      26326          0          0  4.556365e+06    0.0
# 113   2413       2388          0          0  4.192556e+06    0.0
# 83    1301       1190          0          0  6.560448e+06    0.0
# 107   2052       1931          0          0  5.631594e+06    0.0
# 36     145        142          0          0  1.158839e+06    0.0
# 93     342        331          0          0  2.982381e+06    0.0
# 3     2044       1930          0          0  5.053482e+06    0.0
# 106    736        492          0          0  9.673761e+06    0.0

# %%
barsWithoutSoju = tmp[tmp.sojuU==0].barId
barsWithoutSoju
# Out:
# 51     Bar 145
# 49     Bar 143
# 53     Bar 147
# 25     Bar 121
# 59       Bar 2
# 140     Bar 93
# 63      Bar 23
# 70       Bar 3
# 113     Bar 69
# 83      Bar 41
# 107     Bar 63
# 36     Bar 131
# 93      Bar 50
# 3      Bar 101
# 106     Bar 62
# Name: barId, dtype: object

# %% [markdown]
# - It seems there are 15 bars without any soju sales during the observation period
# - These bars are likely that they do not service Soju

# %%
tmp = testData.groupby(['barId','month']).sum()
tmp[tmp.sojuU==0]
# Out:
#                    draughtV  packagedV    totalV    totalR     beerR  beerU  \
# barId   month
# Bar 102 August      330.260     64.285   394.545  33523000  16202900   1815
#         September   663.260    248.910   912.170  86302627  39690200   4906
# Bar 130 October     626.200    130.350   756.550  38243500   6035000   1429
# Bar 29  November    864.000    432.300  1296.300  67551900  10517500   1855
#         October    1021.500    414.810  1436.310  72657000  11247500   1896
#         September  1036.000    432.630  1468.630  70822500  11463500   1935
# Bar 33  August      153.600     58.980   212.580   4545000   2245000    404
#         October     671.740    125.535   797.275  17118500   7434500   1428
#         September   788.970    170.975   959.945  19791500   9347500   1706
# Bar 47  August      204.004     65.670   269.674  42239600   4738000    651
# Bar 55  August      149.500     45.910   195.410   3544000   1323000    385
#         July         38.000     18.500    56.500   1176000    376000    113
#         September    61.000     62.000   123.000   2874000    980000    263
# Bar 58  July        216.300     23.760   240.060   6553100   1594500    451
# Bar 67  October       0.000      0.000     0.000    -62727         0      0
# 4631        0      0     18         18          0          0  40902.777778
# 4632        0      0     15         15          0          0  33396.000000
# 4633        0      0     19         19          0          0  40436.363636
# 4634        0      0     26         25          0          0  35790.000000
# 4635        0      0     56         54          0          0  34500.000000
# 4636        0      0     62         60          0          0  32114.473684
# 4637        0      0     13         13          0          0  27134.210526
# 4638        0      0     13         13          0          0  39780.000000
# 4639        0      0     17         16          0          0  34091.891892
# 4640        0      0     15         15          0          0  42027.586207
# 4641        0      0     31         30          0          0  45254.237288
# 4642        0      0     66         64          0          0  36350.303030
# 4643        0      0     10         10          0          0  29367.741935
# 4644        0      0     14         14          0          0  41167.647059
# 4645        0      0     18         17          0          0  42654.761905
# 4646        0      0     27         27          0          0  47432.758621
# 4647        0      0     23         23          0          0  39508.620690
# 4648  2088000    464     53         51         50        158  39624.705882
# 4649  1035000    230     36         33         32         72  37362.500000
# 4650   333000     74     13         13         13         28  33542.857143
# 4651   378000     84     17         17         16         29  43948.387097
# 4652  1341000    298     36         35         33         93  39633.000000
# 4653        0      0    140        135          0          0  52856.400000
#
#        sojuP     month
# 4478     0.0      July
# 4479     0.0      July
# 4480     0.0      July
# 4481     0.0      July
# 4482     0.0      July
# 4483  2500.0      July
# 4484  2500.0      July
# 4485  2500.0      July
# 4486  2500.0      July
# 4487  2500.0      July
# 4488  2500.0      July
# 4489  2500.0      July
# 4490  2500.0      July
# 4491  2500.0      July
# 4492  2500.0      July
# 4493  2500.0      July
# 4494  2500.0      July
# 4495  2500.0      July
# 4496  2500.0      July
# 4497  2500.0      July
# 4498  2500.0      July
# 4499  2500.0      July
# 4500  2500.0      July
# 4501  2500.0      July
# 4502  2500.0      July
# 4503     0.0      July
# 4504     0.0      July
# 4505  2500.0      July
# 4506  2500.0      July
# 4507     0.0      July
# ...      ...       ...
# 4624     0.0  November
# 4625     0.0  November
# 4626     0.0  November
# 4627     0.0  November
# 4628     0.0  December
# 4629     0.0  December
# 4630     0.0  December
# 4631     0.0  December
# 4632     0.0  December
# 4633     0.0  December
# 4634     0.0  December
# 4635     0.0  December
# 4636     0.0  December
# 4637     0.0  December
# 4638     0.0  December
# 4639     0.0  December
# 4640     0.0  December
# 4641     0.0  December
# 4642     0.0  December
# 4643     0.0  December
# 4644     0.0  December
# 4645     0.0  December
# 4646     0.0  December
# 4647     0.0  December
# 4648  4500.0  December
# 4649  4500.0  December
# 4650  4500.0  December
# 4651  4500.0  December
# 4652  4500.0  December
# 4653     0.0  December
#
# [176 rows x 23 columns]

# %% [markdown]
# - There are also bars where soju sales were 0 on ceratin months.
# - Sampling the bar data, I could note that there is continuity or pattern in the dates with 0 Soju Units
# - I may interview bar owner or employees at OB for more domain information, but relying on my subjective opinion could be misleading the findings: **keep the data**
# ___

# %% [markdown]
# ### impossible values
#
# - negative figures is impossible on daily summed POS data
# - Order counts may have

# %%
# to test if any value in row contains negative value
def detect_integrity(row):
    
    ln = len(row)
    test = 0
    
    for i in range(ln):
        test += (row[i] < 0)
    # test each value and add count if wrong
    
    result = False
    if test != 0:
        result = True
    # if count is not 0, return False
    
    return result

# %%
detectFalseIdx = testData.iloc[:,3:-1].apply(lambda x: detect_integrity(x), axis=1)
testData[detectFalseIdx]
# Out:
#          barId       date segment  draughtV  packagedV  totalV   totalR  \
# 7022    Bar 47 2017-09-06    Food     4.260       1.98   6.240   823700
# 9531    Bar 67 2017-10-31    Food     0.000       0.00   0.000   -62727
# 9971    Bar 70 2017-11-01    Food     3.420       0.33   3.750   449700
# 12178   Bar 91 2017-09-25    Food     9.905      12.31  22.215   675900
# 14268  Bar 111 2017-12-05    Food     4.180      -0.68   3.500  3368500
#
#         beerR  beerU  spiritsR  spiritsU    foodR  nonAlcoholR   wineR  sojuR  \
# 7022   111000     15    -69000       -11   717700        64000       0      0
# 9531        0      0         0         0   -65456            0       0      0
# 9971    72000      8     16000         3   175700         6000  180000 -24000
# 12178  327700     46    -38500        -5   389100         7500       0   8000
# 14268  107000     11    865000        38  2372500        24000       0  70000
#
#        sojuU  beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck    sojuP  \
# 7022       0      5          5          0          0  37440.909091      0.0
# 9531       0      0          0          0          0 -31363.500000      0.0
# 9971      -1      3          3          0          0  56212.500000  24000.0
# 12178      2     16         13          3          3  35573.684211   4000.0
# 14268     14      5          5          4          6  73228.260870   5000.0
#
#            month
# 7022   September
# 9531     October
# 9971    November
# 12178  September
# 14268   December

# %%
testData = testData[~detectFalseIdx]
testData.describe()
# Out:
#            draughtV     packagedV        totalV        totalR         beerR  \
# count  15102.000000  15102.000000  15102.000000  1.510200e+04  1.510200e+04
# mean      22.303292      5.405677     27.708969  1.252212e+06  3.200467e+05
# std       21.914996      7.171120     24.191720  1.633555e+06  3.535163e+05
# min        0.000000      0.000000      0.000000  3.500000e+03  0.000000e+00
# 25%        6.500000      1.065000     10.637000  5.350000e+05  1.083500e+05
# 50%       16.205000      3.300000     21.381500  8.980500e+05  2.144325e+05
# 75%       31.200000      6.930000     37.867500  1.457400e+06  4.000000e+05
# max      415.600000    126.720000    421.540000  4.666240e+07  4.159500e+06
#
#               beerU      spiritsR      spiritsU         foodR   nonAlcoholR  \
# count  15102.000000  1.510200e+04  15102.000000  1.510200e+04  1.510200e+04
# mean      61.224010  1.317371e+05     26.942392  7.517778e+05  2.989395e+04
# std       52.206269  2.041919e+05     43.475003  1.279562e+06  9.121218e+04
# min        0.000000  0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 25%       23.000000  3.200000e+04      7.000000  2.644500e+05  4.000000e+03
# 50%       47.000000  6.909600e+04     15.000000  4.894500e+05  1.200000e+04
# 75%       84.000000  1.480000e+05     30.000000  8.649500e+05  2.600000e+04
# max      439.000000  4.614000e+06    834.000000  4.029460e+07  1.804500e+06
#
#                wineR         sojuR         sojuU         beerO     beerFoodO  \
# count   15102.000000  1.510200e+04  15102.000000  15102.000000  15102.000000
# mean     3127.428486  8.719475e+04     19.892133     17.189180     15.896570
# std     23658.243318  1.243492e+05     27.541863     12.862547     11.938046
# min         0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%         0.000000  1.600000e+04      4.000000      8.000000      7.000000
# 50%         0.000000  5.200000e+04     12.000000     14.000000     13.000000
# 75%         0.000000  1.090660e+05     26.000000     23.000000     21.000000
# max    861000.000000  2.281500e+06    507.000000    211.000000    135.000000
#
#           sojuBeerO     sojuFoodO      avgCheck         sojuP
# count  15102.000000  15102.000000  1.510200e+04  15102.000000
# mean       4.736724      8.058337  3.765822e+04   3663.945248
# std        5.086545      9.328205  3.066831e+04   1945.170449
# min        0.000000      0.000000  2.633333e+03      0.000000
# 25%        1.000000      2.000000  2.468497e+04   4000.000000
# 50%        4.000000      6.000000  3.353280e+04   4000.000000
# 75%        7.000000     11.000000  4.433902e+04   4000.000000
# max       86.000000    158.000000  2.687000e+06  25000.000000

# %% [markdown]
# - There are only four data with negative values
# - There might have been refund from previous day, but since the size of data is not too big, remove the rows for analysis for integrity

# %%
print(len(testData))
print(testData.apply(lambda x: x['beerO'] >= x['beerFoodO'], axis=1).sum())
print(testData.apply(lambda x: x['beerO'] >= x['sojuBeerO'], axis=1).sum())
# Out:
# 15102
# 15102
# 15102

# %% [markdown]
# - Order count derived from "# Beer Orders" do not exceed "# Beer Orders".
# ___

# %% [markdown]
# ### Outliers
#
# - One of the best way to detect outlier/abnomality, is by comparing fixed variable to ratio-base derivative. (For this case, price to revenue/unit)
# - We do not have price information, but if observations from ratio-base derivative is far exceeding (99.7CI, 1.5IQR boundary, or by other measures), it has great potential to be considered as abnormality.
# - I can also check boxplot, distribution of values with own eyes.

# %%
testData['beerP'] = testData.beerR/testData.beerU
testData['spiritsP'] = testData.spiritsR/testData.spiritsU
testData['sojuP'] = testData.sojuR/testData.sojuU
# Out:
# C:\Programming\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Programming\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Programming\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
testData.fillna(0).describe()
# Out:
#            draughtV     packagedV        totalV        totalR         beerR  \
# count  14910.000000  14910.000000  14910.000000  1.491000e+04  1.491000e+04
# mean      22.249057      5.429142     27.678199  1.194797e+06  3.140898e+05
# std       21.902198      7.196742     24.177248  1.388399e+06  3.430160e+05
# min        0.000000      0.000000      0.000000  3.500000e+03  0.000000e+00
# 25%        6.500000      1.160000     10.641500  5.350500e+05  1.085000e+05
# 50%       16.110000      3.300000     21.310000  8.930000e+05  2.130000e+05
# 75%       31.000000      6.930000     37.730500  1.434625e+06  3.931750e+05
# max      415.600000    126.720000    421.540000  4.666240e+07  4.159500e+06
#
#               beerU      spiritsR      spiritsU         foodR   nonAlcoholR  \
# count  14910.000000  1.491000e+04  14910.000000  1.491000e+04  1.491000e+04
# mean      61.348357  1.300206e+05     27.144668  7.105362e+05  2.488713e+04
# std       52.289978  2.029929e+05     43.700447  1.084431e+06  6.547310e+04
# min        0.000000  0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 25%       24.000000  3.200000e+04      7.000000  2.641792e+05  4.000000e+03
# 50%       47.000000  6.813800e+04     15.000000  4.865500e+05  1.150000e+04
# 75%       84.000000  1.460000e+05     31.000000  8.522500e+05  2.546925e+04
# max      439.000000  4.614000e+06    834.000000  4.029460e+07  1.559500e+06
#
#                wineR         sojuR         sojuU         beerO     beerFoodO  \
# count   14910.000000  1.491000e+04  14910.000000  14910.000000  14910.000000
# mean     3081.718645  8.496147e+04     20.004561     17.142924     15.843260
# std     23619.487533  1.203960e+05     27.674366     12.788970     11.853004
# min         0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%         0.000000  1.600000e+04      4.000000      8.000000      7.000000
# 50%         0.000000  5.200000e+04     12.000000     14.000000     13.000000
# 75%         0.000000  1.080000e+05     26.000000     23.000000     21.000000
# max    861000.000000  2.281500e+06    507.000000    211.000000    135.000000
#
#           sojuBeerO     sojuFoodO      avgCheck         sojuP         beerP  \
# count  14910.000000  14910.000000  1.491000e+04  14910.000000  14910.000000
# mean       4.733669      8.076794  3.737906e+04   3829.475905   4992.918504
# std        5.089931      9.360357  3.037974e+04   2517.696423   2059.752981
# min        0.000000      0.000000  2.633333e+03      0.000000      0.000000
# 25%        1.000000      2.000000  2.458909e+04   4000.000000   3780.487805
# 50%        4.000000      6.000000  3.338889e+04   4000.000000   4419.354839
# 75%        7.000000     11.000000  4.403785e+04   4000.000000   5636.988304
# max       86.000000    158.000000  2.687000e+06  46833.333333  44074.025974
#
#             spiritsP
# count   14910.000000
# mean     4982.197358
# std      4359.495780
# min         0.000000
# 25%      4000.000000
# 50%      4000.000000
# 75%      4526.788618
# max    180000.000000

# %%
testData[['beerP', 'spiritsP', 'sojuP']].boxplot()

# %%
testData[['beerP', 'spiritsP', 'sojuP']].describe()
# Out:
#               beerP      spiritsP         sojuP
# count  14994.000000   14533.00000  1.308100e+04
# mean    5111.582502    5347.55432           inf
# std     2296.059355    4771.65956           NaN
# min        0.000000       0.00000  0.000000e+00
# 25%     3791.666667    4000.00000  4.000000e+03
# 50%     4440.297030    4000.00000  4.000000e+03
# 75%     5710.282146    4660.00000  4.000000e+03
# max    44074.025974  180000.00000           inf

# %% [markdown]
# - It has come to my attension that:
#     1. "soju price" still has outlier (`inf`), and
#     2. "spirits price seems very volitle"

# %%
testData.sort_values('sojuP', ascending=False).head()
# Out:
#          barId       date segment  draughtV  packagedV  totalV    totalR  \
# 14435  Bar 113 2017-12-29    Food      4.85      14.24   19.09   2069618
# 14757  Bar 118 2017-10-29    Food      7.50       7.26   14.76   2663500
# 14756  Bar 118 2017-10-28    Food     23.50       0.66   24.16   3434500
# 4405    Bar 28 2017-10-20    Food     71.10       3.92   75.02  10812000
# 12921   Bar 98 2017-11-07    Food     21.00       0.50   21.50   2213000
#
#          beerR  beerU  spiritsR  spiritsU    foodR  nonAlcoholR  wineR  \
# 14435   288646     48    116822         3  1561868        74100      0
# 14757   461000     36    161500         3  1795000       246000      0
# 14756   502000     46    281000         6  2118000       533500      0
# 4405   1570000    104    794000        17  6193000       783000      0
# 12921   399000     42    178000         4  1418000       211000      0
#
#         sojuR  sojuU  beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck  \
# 14435    9092      0     16         16          0          1  42237.102041
# 14757  161500      3      7          7          3          3  47562.500000
# 14756  281000      6     13         12          3          3  47701.388889
# 4405   794000     17     42         41          7         12  62137.931034
# 12921  178000      4      9          9          3          3  58236.842105
#
#               sojuP     month         beerP      spiritsP
# 14435           inf  December   6013.458333  38940.666667
# 14757  5.383333e+04   October  12805.555556  53833.333333
# 14756  4.683333e+04   October  10913.043478  46833.333333
# 4405   4.670588e+04   October  15096.153846  46705.882353
# 12921  4.450000e+04  November   9500.000000  44500.000000

# %%
testData = testData[testData.index!=14435]
testData[['beerP', 'spiritsP', 'sojuP']].describe()
# Out:
#               beerP       spiritsP         sojuP
# count  14993.000000   14532.000000  13080.000000
# mean    5111.522349    5345.242655   4613.777682
# std     2296.124115    4763.678743   2991.856464
# min        0.000000       0.000000      0.000000
# 25%     3791.666667    4000.000000   4000.000000
# 50%     4440.000000    4000.000000   4000.000000
# 75%     5710.191083    4658.421053   4000.000000
# max    44074.025974  180000.000000  53833.333333

# %% [markdown]
# - Impossible value on soju Price fixed
# - Although the derivatives do not seem to follow normal distribution, the definition of price should follow normal distribution.
# - Data exceeding relative price outside 99.7% credential interval (3std from mean) can be considered outlier.
# - Also the count of observasions vary and it might have been because of NAs.

# %%
tmp = testData[['beerP', 'spiritsP', 'sojuP']].describe()
beerLimit = tmp.loc['mean', 'beerP'] + 3* tmp.loc['std','beerP']
sojuLimit = tmp.loc['mean', 'sojuP'] + 3* tmp.loc['std','sojuP']
spiritsLimit = tmp.loc['mean', 'spiritsP'] + 3* tmp.loc['std','spiritsP']

# %%
print(sum(testData.beerP>=beerLimit), sum(testData.sojuP>=sojuLimit), sum(testData.spiritsP>=spiritsLimit))

print(len(testData[(testData.beerP>=beerLimit) | (testData.sojuP>=sojuLimit) | (testData.spiritsP>=spiritsLimit)]))
# Out:
# 322 370 319
# 602

# %% [markdown]
# - 602 observations are suspicious of abnormality: remove

# %%
idx = ((testData.beerP>=beerLimit) | (testData.sojuP>=sojuLimit) | (testData.spiritsP>=spiritsLimit))
testData = testData[~idx]
testData.head()
# Out:
#    barId       date       segment  draughtV  packagedV  totalV  totalR  \
# 0  Bar 1 2017-07-01  Food,Spirits       9.3       6.16   15.46  887100
# 1  Bar 1 2017-07-02  Food,Spirits      21.3       2.50   23.80  745800
# 2  Bar 1 2017-07-03  Food,Spirits       9.3       2.50   11.80  575100
# 3  Bar 1 2017-07-04  Food,Spirits      15.9       7.50   23.40  553500
# 4  Bar 1 2017-07-05  Food,Spirits       1.7       8.00    9.70  256600
#
#     beerR  beerU  spiritsR  spiritsU   foodR  nonAlcoholR  wineR  sojuR  \
# 0  124500     22    278000        68  461100        23500      0  54000
# 1  167500     16    256000        63  298300        24000      0  18000
# 2   87000     12    237000        57  234100        10000      0  27000
# 3  178000     26    146000        35  222500         4000      0  27000
# 4   84000     17     80500        20   92100            0      0   4500
#
#    sojuU  beerO  beerFoodO  sojuBeerO  sojuFoodO      avgCheck   sojuP month  \
# 0     12     14         14          1          7  26881.818182  4500.0  July
# 1      4      7          7          1          2  46612.500000  4500.0  July
# 2      5      7          7          2          4  26140.909091  5400.0  July
# 3      5     12         12          2          4  34593.750000  5400.0  July
# 4      1      7          7          1          1  28511.111111  4500.0  July
#
#           beerP     spiritsP
# 0   5659.090909  4088.235294
# 1  10468.750000  4063.492063
# 2   7250.000000  4157.894737
# 3   6846.153846  4171.428571
# 4   4941.176471  4025.000000

# %%
testData[testData.beerP.isna()].head(10)
# Out:
# Empty DataFrame
# Columns: [barId, date, segment, draughtV, packagedV, totalV, totalR, beerR, beerU, spiritsR, spiritsU, foodR, nonAlcoholR, wineR, sojuR, sojuU, beerO, beerFoodO, sojuBeerO, sojuFoodO, avgCheck, sojuP, month, beerP, spiritsP]
# Index: []

# %% [markdown]
# - The NAs have been created dividing by 0 units.
# - Simply replace NAs to zero to complete data.

# %%
testData = testData.fillna(0)
testData.describe()
# Out:
#            draughtV     packagedV        totalV        totalR         beerR  \
# count  14450.000000  14450.000000  14450.000000  1.445000e+04  1.445000e+04
# mean      22.230620      5.346046     27.576667  1.126769e+06  3.024830e+05
# std       21.630996      7.000085     23.916056  9.099753e+05  3.205761e+05
# min        0.000000      0.000000      0.000000  3.500000e+03  0.000000e+00
# 25%        6.500000      1.280000     10.672500  5.285000e+05  1.075000e+05
# 50%       16.200000      3.300000     21.260000  8.795000e+05  2.095500e+05
# 75%       31.000000      6.930000     37.490000  1.409420e+06  3.823250e+05
# max      208.900000    126.720000    283.720000  1.321410e+07  3.468300e+06
#
#               beerU      spiritsR      spiritsU         foodR    nonAlcoholR  \
# count  14450.000000  1.445000e+04  14450.000000  1.445000e+04   14450.000000
# mean      61.069204  1.273705e+05     27.591349  6.643887e+05   20024.369827
# std       51.821319  2.026173e+05     44.259963  6.315910e+05   28426.786045
# min        0.000000  0.000000e+00      0.000000  0.000000e+00       0.000000
# 25%       24.000000  3.200000e+04      7.000000  2.630738e+05    4000.000000
# 50%       47.000000  6.800000e+04     16.000000  4.845000e+05   11000.000000
# 75%       84.000000  1.400000e+05     31.000000  8.415000e+05   24000.000000
# max      439.000000  4.614000e+06    834.000000  8.266700e+06  460000.000000
#
#                wineR         sojuR         sojuU         beerO     beerFoodO  \
# count   14450.000000  1.445000e+04  14450.000000  14450.000000  14450.000000
# mean     2550.617024  8.359015e+04     20.326851     17.057716     15.791696
# std     18898.797696  1.181267e+05     27.972809     12.644377     11.746465
# min         0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%         0.000000  1.600000e+04      4.000000      8.000000      7.000000
# 50%         0.000000  5.200000e+04     13.000000     14.000000     13.000000
# 75%         0.000000  1.077722e+05     26.000000     23.000000     21.000000
# max    512000.000000  2.281500e+06    507.000000    211.000000    135.000000
#
#           sojuBeerO     sojuFoodO       avgCheck         sojuP         beerP  \
# count  14450.000000  14450.000000   14450.000000  14450.000000  14450.000000
# mean       4.801315      8.193702   36367.899477   3596.440396   4803.560298
# std        5.123883      9.445418   17282.668924   1487.877906   1511.254473
# min        0.000000      0.000000    2633.333333      0.000000      0.000000
# 25%        1.000000      2.000000   24416.918363   4000.000000   3767.053063
# 50%        4.000000      6.000000   33020.089285   4000.000000   4377.429245
# 75%        7.000000     11.000000   43179.808959   4000.000000   5457.309942
# max       86.000000    158.000000  355333.333333  13272.222222  11974.285714
#
#            spiritsP
# count  14450.000000
# mean    4489.029108
# std     1990.389597
# min        0.000000
# 25%     4000.000000
# 50%     4000.000000
# 75%     4400.000000
# max    19625.000000

# %% [markdown]
# ### Preliminary variable selection / normalization
#
# - Given the purpose of analysis, I will have `Beer Units`(demand for beer) for dependent variable, and other variables on the other side to explain beer demand.
# - I will have regression to how much impact soju demand has on beer units, and will also have CART to see wich explanatory variable is  most relevant to determine beer demand, given dataset.
# - I will priliminarily select variables based on rational ground, and normalize them if necessary for regression.

# %% [markdown]
# 1. Volume over Revenue:
#     - Revenue and volume are highly correlated, and need to choose one over the other.
#     - In this case, volume is more directly related to customer demand as revenue is outcome after unit x price, where price can be effected by externalities (i.e. promotion)
#
#
# 2. Avoid duplication:
#     - Variable like "Total Volume(L)" is simply a sum of draught and packaged volume, which then is duplication of information and could cause multicollinearity.
#     - Keep the detailed ones, omit aggregated information

# %%
testSet = testData.loc[:, ['barId', 'segment', 'date', 'month',
                           'draughtV', 'packagedV', 'beerU', 'spiritsU',
                           'foodR', 'nonAlcoholR', 'beerO', 'beerFoodO', 'sojuBeerO', 'sojuFoodO',
                           'avgCheck', 'sojuP', 'beerP', 'spiritsP']]

# %%
testSet.describe()
# Out:
#            draughtV     packagedV         beerU      spiritsU         foodR  \
# count  14450.000000  14450.000000  14450.000000  14450.000000  1.445000e+04
# mean      22.230620      5.346046     61.069204     27.591349  6.643887e+05
# std       21.630996      7.000085     51.821319     44.259963  6.315910e+05
# min        0.000000      0.000000      0.000000      0.000000  0.000000e+00
# 25%        6.500000      1.280000     24.000000      7.000000  2.630738e+05
# 50%       16.200000      3.300000     47.000000     16.000000  4.845000e+05
# 75%       31.000000      6.930000     84.000000     31.000000  8.415000e+05
# max      208.900000    126.720000    439.000000    834.000000  8.266700e+06
#
#          nonAlcoholR         beerO     beerFoodO     sojuBeerO     sojuFoodO  \
# count   14450.000000  14450.000000  14450.000000  14450.000000  14450.000000
# mean    20024.369827     17.057716     15.791696      4.801315      8.193702
# std     28426.786045     12.644377     11.746465      5.123883      9.445418
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      4000.000000      8.000000      7.000000      1.000000      2.000000
# 50%     11000.000000     14.000000     13.000000      4.000000      6.000000
# 75%     24000.000000     23.000000     21.000000      7.000000     11.000000
# max    460000.000000    211.000000    135.000000     86.000000    158.000000
#
#             avgCheck         sojuP         beerP      spiritsP
# count   14450.000000  14450.000000  14450.000000  14450.000000
# mean    36367.899477   3596.440396   4803.560298   4489.029108
# std     17282.668924   1487.877906   1511.254473   1990.389597
# min      2633.333333      0.000000      0.000000      0.000000
# 25%     24416.918363   4000.000000   3767.053063   4000.000000
# 50%     33020.089285   4000.000000   4377.429245   4000.000000
# 75%     43179.808959   4000.000000   5457.309942   4400.000000
# max    355333.333333  13272.222222  11974.285714  19625.000000

# %%
sns.heatmap(testSet.corr(), vmin=-1, vmax=1, annot=True)

# %% [markdown]
# - Remove "Beer & Food Orders", "Soju & Food Orders", as they are highly correlated.
# - This may imply **strong characteristics of Korean customers drinking while having a meal.**

# %%
testSet = testSet.drop(['beerFoodO', 'sojuFoodO'], axis=1)

# %%
g = sns.FacetGrid(data=testSet.iloc[:,4:].melt(), col = 'variable', col_wrap = 4, sharey=False, sharex=False)
g.map(sns.distplot, 'value')
plt.suptitle("The distribution of values in variables", y = 1.05)
# Out:
# Text(0.5, 1.05, 'The distribution of values in variables')

# %% [markdown]
# Normalize
