# %%
import sys

from google.api_core.client_options import ClientOptions
from google.cloud import automl_v1
from google.cloud.automl_v1.proto import service_pb2

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALs'] = 'c:/automatic-honor-251707-2a0c46fd7736.json'

# %%
def inline_text_payload(file_path):
    with open(file_path, 'rb') as ff:
        content = ff.read()
    return {'text_snippet': {'content': content, 'mime_type': 'text/plain'} }

def pdf_payload(file_path):
    return {'document': {'input_config': {'gcs_source': {'input_uris': [file_path] } } } }

def get_prediction(file_path, model_name):
    options = ClientOptions(api_endpoint='automl.googleapis.com' )
    prediction_client = automl_v1.PredictionServiceClient(client_options=options)

    payload = inline_text_payload(file_path)
  # Uncomment the following line (and comment the above line) if want to predict on PDFs.
  # payload = pdf_payload(file_path)

    params = {}
    request = prediction_client.predict(model_name, payload, params)
    return request  # waits until request is returned

if __name__ == '__main__':
    file_path = sys.argv[0]
    model_name = sys.argv[1]

# %%
get_prediction('text_classification/ShoppingToneNManner/text45.txt', 'projects/721541100077/locations/us-central1/models/TCN5423015648563298304')
# Out:
# payload {
#   annotation_spec_id: "3715498279882981376"
#   classification {
#     score: 0.9212066531181335
#   }
#   display_name: "ShoppingToneNManner"
# }
# payload {
#   annotation_spec_id: "256733766062440448"
#   classification {
#     score: 0.13386547565460205
#   }
#   display_name: "ShoppingEaseOfshopping"
# }
# payload {
#   annotation_spec_id: "2130231211048566784"
#   classification {
#     score: 0.1210489571094513
#   }
#   display_name: "ShoppingGetting support"
# }
# payload {
#   annotation_spec_id: "9047760238689648640"
#   classification {
#     score: 0.08591556549072266
#   }
#   display_name: "IKEAProcess"
# }
# payload {
#   annotation_spec_id: "4436074220262260736"
#   classification {
#     score: 0.017993807792663574
#   }
#   display_name: "ProductQuality"
# }
# payload {
#   annotation_spec_id: "1409655270669287424"
#   classification {
#     score: 0.01728653907775879
#   }
#   display_name: "CSCToneNManner"
# }
# payload {
# ...
