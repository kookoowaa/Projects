# %%
import pandas as pd
import json
import seaborn as sns

# %%
match = json.loads(open('match1.json', 'r').read())['matches']
match[0].keys()
# Out:
# dict_keys(['gameId', 'platformId', 'gameCreation', 'gameDuration', 'queueId', 'mapId', 'seasonId', 'gameVersion', 'gameMode', 'gameType', 'teams', 'participants', 'participantIdentities'])

# %%
match[1]
# Out:
# {'gameCreation': 1538662571675,
#  'gameDuration': 2282,
#  'gameId': 3369534997,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '8.19.246.5109',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#    'player': {'accountId': 206119042,
#     'currentAccountId': 206119042,
#     'currentPlatformId': 'KR',
#     'matchHistoryUri': '/v1/stats/player_history/KR/206119042',
#     'platformId': 'KR',
#     'profileIcon': 1665,
#     'summonerId': 36100660,
#     'summonerName': 'only효누'}},
#   {'participantId': 2,
#    'player': {'accountId': 208460533,
#     'currentAccountId': 208460533,
#     'currentPlatformId': 'KR',
#     'matchHistoryUri': '/v1/stats/player_history/KR/208460533',
#     'platformId': 'KR',
#     'profileIcon': 3374,
#     'summonerId': 52192356,
#     'summonerName': '순시려'}},
#   {'participantId': 3,
#    'player': {'accountId': 6122412,
#     'currentAccountId': 6122412,
#     'currentPlatformId': 'KR',
# ...

# %%
team = []
for i in range(1,51):
    if i ==1:
        match = json.loads(open('match1.json', 'r').read())['matches']
    else:
        match = json.loads('{"matches": ['+open('match{}.json'.format(i), 'r').read())['matches']
    
    for k in match:
        if k['gameMode'] == 'CLASSIC':
            team.extend(k['teams'])

# %%
team = pd.DataFrame(team).iloc[:,1:]
team.columns = [i.lower() for i in team.columns]

# %%
team.groupby(['win', 'teamid'], as_index = False).count().iloc[:,:3]
# Out:
#     win  teamid  baronkills
# 0  Fail     100        1137
# 1  Fail     200        1261
# 2   Win     100        1261
# 3   Win     200        1137

# %%
import statsmodels.api as sm

y = np.zeros_like(team.win)
y[team.win=='Win']=1
X = team.iloc[:,:-1]

# %%
sm.OLS(y, X).fit().summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-da36a3754b7d> in <module>()
# ----> 1 sm.OLS(y, X).fit().summary()
#
# C:\Programming\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in summary(self, yname, xname, title, alpha)
#    2406                              yname=yname, xname=xname, title=title)
#    2407         smry.add_table_params(self, yname=yname, xname=xname, alpha=alpha,
# -> 2408                               use_t=self.use_t)
#    2409
#    2410         smry.add_table_2cols(self, gleft=diagn_left, gright=diagn_right,
#
# C:\Programming\Anaconda3\lib\site-packages\statsmodels\iolib\summary.py in add_table_params(self, res, yname, xname, alpha, use_t)
#     862         if res.params.ndim == 1:
#     863             table = summary_params(res, yname=yname, xname=xname, alpha=alpha,
# ...

# %%
X.firstbaron = [int(i) for i in X.firstbaron]
X.firstblood = [int(i) for i in X.firstblood]
X.firstdragon = [int(i) for i in X.firstdragon]
X.firstinhibitor = [int(i) for i in X.firstinhibitor]
X.firstriftherald = [int(i) for i in X.firstriftherald]
X.firsttower = [int(i) for i in X.firsttower]
X = np.asarray(X)

# %%
team.groupby('win').mean()
# Out:
#       baronkills  dominionvictoryscore  dragonkills  firstbaron  firstblood  \
# win
# Fail    0.123436                   0.0     0.677231    0.095496    0.382819
# Win     0.495413                   0.0     1.748123    0.403253    0.613428
#
#       firstdragon  firstinhibitor  firstriftherald  firsttower  \
# win
# Fail     0.276480        0.070892         0.149291    0.260634
# Win      0.663887        0.713928         0.357798    0.723103
#
#       inhibitorkills  riftheraldkills    teamid  towerkills  vilemawkills
# win
# Fail        0.155129         0.149291  0.525855    2.333194      0.000000
# Win         1.510842         0.357798  0.474145    7.854462      0.000417

# %%
match[0]['participants'][0].keys()
# Out:
# dict_keys(['participantId', 'teamId', 'championId', 'spell1Id', 'spell2Id', 'highestAchievedSeasonTier', 'stats', 'timeline'])

# %%
match[0]['participants'][0]
# Out:
# {'championId': 3,
#  'highestAchievedSeasonTier': 'GOLD',
#  'participantId': 1,
#  'spell1Id': 32,
#  'spell2Id': 4,
#  'stats': {'assists': 14,
#   'champLevel': 16,
#   'combatPlayerScore': 0,
#   'damageDealtToObjectives': 178,
#   'damageDealtToTurrets': 178,
#   'damageSelfMitigated': 33917,
#   'deaths': 10,
#   'doubleKills': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstInhibitorAssist': False,
#   'firstInhibitorKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'goldEarned': 9976,
#   'goldSpent': 9600,
#   'inhibitorKills': 0,
#   'item0': 3029,
#   'item1': 3111,
#   'item2': 3742,
#   'item3': 3075,
#   'item4': 0,
#   'item5': 0,
#   'item6': 2052,
#   'killingSprees': 0,
#   'kills': 4,
#   'largestCriticalStrike': 17,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 154,
#   'magicDamageDealt': 45939,
#   'magicDamageDealtToChampions': 13165,
#   'magicalDamageTaken': 3500,
# ...

# %%
match[0]
# Out:
# {'gameCreation': 1538664039137,
#  'gameDuration': 2061,
#  'gameId': 3369539900,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '8.19.246.5109',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#    'player': {'accountId': 1956614301208160,
#     'currentAccountId': 1956614301208160,
#     'currentPlatformId': 'KR',
#     'matchHistoryUri': '/v1/stats/player_history/KR/1956614301208160',
#     'platformId': 'KR',
#     'profileIcon': 3587,
#     'summonerId': 71790777,
#     'summonerName': '쥰      스'}},
#   {'participantId': 2,
#    'player': {'accountId': 1383678,
#     'currentAccountId': 1383678,
#     'currentPlatformId': 'KR',
#     'matchHistoryUri': '/v1/stats/player_history/KR/1383678',
#     'platformId': 'KR',
#     'profileIcon': 1114,
#     'summonerId': 1872113,
#     'summonerName': '욱 뿌'}},
#   {'participantId': 3,
#    'player': {'accountId': 1265209,
#     'currentAccountId': 1265209,
#     'currentPlatformId': 'KR',
# ...

# %%
match[0]['teams']
# Out:
# [{'bans': [{'championId': 7, 'pickTurn': 1},
#    {'championId': 38, 'pickTurn': 2},
#    {'championId': 497, 'pickTurn': 3},
#    {'championId': 39, 'pickTurn': 4},
#    {'championId': 555, 'pickTurn': 5}],
#   'baronKills': 1,
#   'dominionVictoryScore': 0,
#   'dragonKills': 0,
#   'firstBaron': True,
#   'firstBlood': False,
#   'firstDragon': False,
#   'firstInhibitor': True,
#   'firstRiftHerald': False,
#   'firstTower': False,
#   'inhibitorKills': 1,
#   'riftHeraldKills': 0,
#   'teamId': 100,
#   'towerKills': 8,
#   'vilemawKills': 0,
#   'win': 'Win'},
#  {'bans': [{'championId': 84, 'pickTurn': 6},
#    {'championId': 28, 'pickTurn': 7},
#    {'championId': 122, 'pickTurn': 8},
#    {'championId': 203, 'pickTurn': 9},
#    {'championId': 555, 'pickTurn': 10}],
#   'baronKills': 1,
#   'dominionVictoryScore': 0,
#   'dragonKills': 2,
#   'firstBaron': False,
#   'firstBlood': True,
#   'firstDragon': True,
#   'firstInhibitor': False,
#   'firstRiftHerald': False,
# ...

# %%
[i['gameMode'] for i in match]
# Out:
# ['CLASSIC',
#  'CLASSIC',
#  'ODYSSEY',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'ARAM',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'ARAM',
#  'CLASSIC',
#  'ARAM',
#  'CLASSIC',
#  'ODYSSEY',
#  'CLASSIC',
#  'ARAM',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'ARAM',
#  'ARAM',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'ARAM',
#  'ARAM',
#  'ODYSSEY',
#  'TUTORIAL_MODULE_3',
#  'CLASSIC',
#  'ARAM',
#  'CLASSIC',
#  'ARAM',
#  'ARAM',
#  'CLASSIC',
#  'CLASSIC',
#  'ARAM',
#  'CLASSIC',
#  'ARAM',
#  'ARAM',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC',
#  'ODYSSEY',
#  'ARAM',
#  'CLASSIC',
#  'CLASSIC',
#  'CLASSIC']

# %%
len(json.loads('{"matches": ['+open('match2.json', 'r').read())['matches'])
# Out:
# 75
