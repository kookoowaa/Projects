# %% [markdown]
# > ### DATA 수집

# %%
import os
import sys
import urllib.request
import json
#from bs4 import BeautifulSoup as bs
client_id = "YOUR KEY/PASS HERE"
client_secret = "YOUR KEY/PASS HERE"
rq = []
encText = urllib.parse.quote("풀무원")
start_point = np.arange(1,1001,100)

# %% [markdown]
# - rq에 for문 사용 1000개 쿼리 반환

# %%
for i in (start_point):
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + '&display=100&start=' + str(i)# json 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    response_body = response.read()
    for i in range(100):
        rq.append(json.loads(response_body.decode('utf-8'))['items'][i])

# %% [markdown]
# - Json 형식으로 읽어서 UTF-8로 디코딩
# - 원하는 데이터가 속해 있는 ['items']의 데이터만 수집해서 rq에 저장

# %%
naver = {'blogger': [], 'description': [], 'postdate':[], 'title':[]}

for i in range(len(rq)):
    naver['blogger'].append(rq[i]['bloggername'])
    naver['description'].append(rq[i]['description'])
    naver['postdate'].append(rq[i]['postdate'])
    naver['title'].append(rq[i]['title'])

# %% [markdown]
# - item 종류 별로 분류
#
# ___

# %% [markdown]
# > ### DATA 정제

# %%
import re
from pandas import DataFrame

# %%
for i in range(len(naver['description'])):
    naver['description'][i] = re.sub('[ㄱ-ㅎ]+', '', re.sub('</?[a-zA-Z]+>', '', re.sub('&[a-zA-Z]+;', '',naver['description'][i])))
    naver['title'][i] = re.sub('[ㄱ-ㅎ]+', '', re.sub('</?[a-zA-Z]+>', '', re.sub('&[a-zA-Z]+;', '',naver['title'][i])))

# %%
naverdf = DataFrame(naver)
naverdf
# Out:
#                      blogger  \
# 0               61801 STUDIO
# 1                 Rainy Days
# 2           하리미지니의 story - ★
# 3                ♥알콩달콩 양송이네♥
# 4                  함께해서 특별한♥
# 5     살림에 감성한스푼, 감성리빙전문가 슈카롱
# 6    행주치마의 제철먹거리와 집밥 도시락 이야기
# 7                   미소천사 양도윤
# 8         Lovely 아롱다롱 ~ ^-^♡
# 9          노숙페이스의 "TalkTalk"
# 10                 꼼지락 롱쓰 :)
# 11           ♥ 마리안느의 꿈꾸는 다락방
# 12                   먀+돈=빠름❤
# 13         당신으로 인해 참 재미난 세상!
# 14             TAZIE FACTORY
# 15              늙지 않는 블로그...
# 16       블랙러시안의 문화&패션&뷰티 트렌드
# 17              냐옹냐옹 최매력☆뷰스타
# 18                   뚱고의바쁜하루
# 19                   theLucy
# 20                별 것 없는 사생활
# 21          하리미지니의 story - ★
# 22             소 녀 다 큐 멘 터 리
# 23              윤설탕♡ 설탕바른다락방
# 24             드래곤스카이의 싱글라이프
# 25            sweet-smelling
# 26               #얼양, 꿈꾸는 아이
# 27                   풀무원건강생활
# 28                 달미의 맛있는하루
# 29                여정 여행&패션로그
# ..                       ...
# 970      부산페인트 시공 Well Paint
# 971                 EuphoPia
# 972          심심해서 다시 시작한 블로그
# 973                소피스트 아뜰리에
# 974                율짱의 상상노트♡
# 975                     쁜소월드
# 976              또다른행복의시작...
# 977          * 쏘콩이네 먹부림하우스 *
# 978                함께해서 특별한♥
# 979                   시안언니옷장
# 23                    풀무원샘물 어린이 생수로도 굳뜨!
# 24            풀무원 생면식감 탱탱비빔쫄면 (2018. 06)
# 25                   여름별미 풀무원 순메밀 물냉면 후기
# 26         마켓컬리 네번째 구매기♥ - 달달한 풀무원 국물떡볶이
# 27          워라밸 제대로인 그녀들! 풀무원로하스 헬스어드바이저
# 28              중기 이유식시작! 풀무원 베이비밀 하루2번씩
# 29   얼려먹는 풀무원다논 그릭프로즌! 100% 그릭요거트라 완전 진해
# ..                                   ...
# 970          풀무원 순메밀물냉면 - 내 돈주고 사먹는 솔직리뷰
# 971                       [풀무원] 생면식감 매운맛
# 972                     토이쿠키만들기(풀무원 생가득)
# 973                    풀무원 핫칠리크랩면 먹어본 후기
# 974                  후기이유식 풀무원 베이비밀 잘먹어요
# 975              다이어트 도시락~풀무원 잇슬림 생생후기예요
# 976              풀무원나또 :: 낫또다이어트 시작해볼까~?
# 977                아기 이유식 풀무원 베이비밀 시켜먹어요
# 978              배달 이유식 :: 풀무원으로 초기부터 시작
# 979                      풀무원 생가득 모짜렐라핫도그
# 980  집밥 백선생 백종원 콩나물찜콩나물전 with풀무원 국산콩...
# 981    맥주안주 풀무원 눈꽃만두 만드는법, 맛있게 먹는 나만의 팁!
# 982        우리 아기유산균 풀무원 프로바이오락 베이비 튼튼 :)
# 983                   배달이유식은 역시나 풀무원베이비밀
# 984                      풀무원 콩비지찌개 마시땅^^
# 985         풀무원 돈코츠라멘 국수나무의 제주고기국수 맛인데??
# 986              배달 이유식 유아유산균 모두 풀무원베이비밀
# 987             [풀무원]풀무원라인톡/풀무원 라인톡 다이어트
# 988      풀무원 비법간장소스~ 샐러드,채소어묵 간장파스타,납작만두
# 989              배달 이유식 풀무원베이비밀로 매일 신선하게
# 990                    우리집 생수는 풀무원 샘물!!!
# 991  풀무원 새우듬뿍만두 정말 맛있네요. 풀무원 만두로 냉동실 든든~
# 992               풀무원 배달이유식 유아유산균 함께 먹어요
# 993               풀무원~곰탕칼국수 죤맛 인정합니다요~^^
# 994   풀무원로하스 데일리 칼슘 튼튼한 뼈 건강을 위한 맛있는...
# 995       풀무원 돈코츠라멘 면 따로 끓여 헹구고 먹어야 맛있어요
# 996       네가 찾고싶은 라인을 말해봐~  /풀무원 그린체 라인톡
# 997        풀무원녹즙, 건강 챙길 수 있는 하트러브 레드비트당근
# 998                쿠키만들기 - 풀무원 토이쿠키 만들기.
# 999                 시판이유식 풀무원베이비키즈 먹여봤어요
#
# [1000 rows x 4 columns]

# %% [markdown]
# - 보기 편하게 dataframe화
# - **이하 데이터 프레임 저장 후 호출해서 작업**
# ___

# %%
import pickle

with open("naver.lq", "wb") as file:
    pickle.dump(naverdf, file)

# %%
import pickle

with open("naver.lq", "rb") as file:
    naverdf = pickle.load(file)

# %% [markdown]
# ___
# > ### 형태소 추출

# %%
from collections import Counter
from konlpy.tag import Hannanum
import pytagcloud
import jpype

# %%
des_str = ''
for i in naverdf['description']:
    des_str = des_str + i + ' '

# %%
nlp = Hannanum()
nouns = nlp.nouns(des_str)
nouns = [i for i in nouns if len(i)>1]

# %%
count = Counter(nouns)
tags2 = count.most_common(201)[1:]
taglist = pytagcloud.make_tags(tags2, maxsize=80)
pytagcloud.create_tag_image(taglist, 'pulmuone.jpg', size=(900, 600), fontname='korean', rectangular=False)

# %% [markdown]
# ![](pulmuone.jpg)

# %%
DataFrame(tags2[0:10], columns = ['Words', 'Counts'])
# Out:
#    Words  Counts
# 0   베이비밀     276
# 1    이유식     152
# 2  배달이유식     102
# 3   생면식감      85
# 4     제품      82
# 5     건강      82
# 6     배달      79
# 7  돈코츠라멘      79
# 8     시작      73
# 9     오늘      73

# %% [markdown]
# ___
# ref to http://cafe.daum.net/oracleoracle/SPY3/17?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C
# > ### 스크립트 실행 단계
# 1) JAVA JDK 설치 (파이썬 설치 비트에 맞는 JAVA JDK를 설치 - 파이썬이 32bit면 JDK도 32bit, 파이썬이 64면 JDK도 64로)
#
# >2) http://withcoding.com/24 를 참조하여 JDK 설치 후 환경변수 경로를 잡아줍니다.
#
# >3) http://landinghub.visualstudio.com/visual-cpp-build-tools 링크를 들어가서 Visual C++ 2015를 설치합니다.
#
# >4) 파이썬 모듈 JPype1-py3를 설치합니다.
#
# >5) 파이썬 모듈 simplejson을 설치합니다.
#
# >6) 파이썬 모듈 pytagcloud를 설치합니다.
#
# >7) 파이썬 모듈 konlpy를 설치합니다.
#
# >8) 파이썬설치폴더\site-packages\pytagcloud\fonts로 이동해서 사용할 한글 폰트를 akoreanL.ttf 로 이름 변경하여 넣어줍니다.
#
# >9) 노트패드++를 관리자권한으로 실행한 후 8번 경로안에 있는 fonts.json 파일을 엽니다.
#
# >10) {
#
# >        "name": "korean",
# 		"ttf": "akoreanL.ttf",
# 		"web": "http://fonts.googleapis.com/css?family=Nobile"
# 	},
#      를 첨가해 주고 저장을 합니다.
#
# >11) 스크립트를 실행합니다.
#
# >12) 지정한 위치에 wordcloud.jpg 파일이 생성되어 있습니다.

# %%
import pandas as pd

# %%
naverdf.head()
# Out:
#             blogger                                        description  \
# 0      61801 STUDIO  네이버에서 그냥 풀무원 이유식을 검색해서 공홈으로 들어가면 쉽게 주문할 수 있도록 ...
# 1        Rainy Days  그 중에 풀무원은 무료 샘플 신청이 간단하길래 도전해보았습니다! (무조건은 아니고 ...
# 2  하리미지니의 story - ★  안녕하세요~ 하리미지니에요, 우리 하지니 초기부터 후기를 진행하는 지금까지 이유식배...
# 3       ♥알콩달콩 양송이네♥  오늘로 281일, 만9개월인 선물이는 6월초부터 풀무원 베이비밀 후기이유식을 시작했...
# 4         함께해서 특별한♥  저는 풀무원 베이비밀로 초기부터 지금까지 쭈욱 먹이고 있거든요. 단계를 하나씩 올릴...
#
#    postdate                         title
# 0  20180607          2주간 이용한 풀무원 배달이유식 후기
# 1  20180623         풀무원 이유식 배달 샘플체험 솔직후기!
# 2  20180624        이유식배달 풀무원 베이비밀 오늘도 먹방~
# 3  20180621        후기 배달이유식도 역시 풀무원 베이비밀!
# 4  20180611  후기이유식 풀무원 베이비밀로 폭풍먹방의 끝을 달리다

# %%
freq_by_acc = Counter(naverdf['postdate'])
freq_by_acc
# Out:
# Counter({'20160929': 1,
#          '20161021': 1,
#          '20161023': 1,
#          '20170125': 1,
#          '20170130': 1,
#          '20170310': 1,
#          '20170324': 1,
#          '20170328': 1,
#          '20170403': 1,
#          '20170418': 1,
#          '20170424': 1,
#          '20170425': 3,
#          '20170426': 3,
#          '20170605': 1,
#          '20170612': 1,
#          '20170616': 3,
#          '20170617': 2,
#          '20170620': 1,
#          '20170629': 1,
#          '20170706': 1,
#          '20170707': 2,
#          '20170714': 1,
#          '20170717': 2,
#          '20170719': 1,
#          '20170725': 1,
#          '20170801': 3,
#          '20170802': 2,
#          '20170816': 1,
#          '20170817': 3,
#          '20170820': 1,
#          '20170824': 2,
#          '20170825': 5,
#          '20170902': 1,
#          '20170906': 1,
#          '20170908': 1,
#          '20170912': 1,
#          '20170915': 1,
#          '20170916': 1,
#          '20170917': 1,
#          '20170919': 1,
#          '20170927': 3,
#          '20170928': 1,
#          '20171003': 1,
#          '20171007': 1,
#          '20171008': 1,
#          '20171010': 2,
#          '20171013': 1,
#          '20171020': 1,
#          '20171025': 1,
#          '20171028': 1,
#          '20171030': 2,
#          '20171106': 1,
#          '20171107': 1,
#          '20171110': 2,
#          '20171111': 3,
#          '20171112': 1,
#          '20171113': 1,
#          '20171115': 1,
#          '20171116': 1,
#          '20171117': 2,
#          '20171118': 1,
#          '20171119': 3,
#          '20171120': 2,
#          '20171122': 2,
#          '20171123': 4,
#          '20171124': 1,
#          '20171126': 1,
#          '20171128': 2,
#          '20171129': 3,
#          '20171130': 1,
#          '20171201': 2,
#          '20171206': 1,
#          '20171207': 1,
#          '20171208': 1,
#          '20171209': 1,
#          '20171210': 3,
#          '20171211': 1,
#          '20171212': 3,
#          '20171215': 1,
#          '20171216': 1,
#          '20171218': 1,
#          '20171219': 2,
#          '20171220': 6,
#          '20171221': 1,
#          '20171222': 4,
#          '20171224': 2,
#          '20171225': 2,
#          '20171226': 2,
#          '20171227': 2,
#          '20171228': 4,
#          '20171229': 2,
#          '20171231': 1,
#          '20180101': 1,
#          '20180102': 3,
#          '20180103': 1,
#          '20180108': 2,
#          '20180109': 5,
#          '20180110': 4,
#          '20180111': 1,
#          '20180112': 4,
#          '20180113': 1,
#          '20180114': 1,
#          '20180115': 3,
#          '20180116': 3,
#          '20180117': 6,
#          '20180118': 4,
#          '20180119': 2,
#          '20180120': 2,
#          '20180121': 7,
#          '20180122': 4,
#          '20180123': 6,
#          '20180124': 4,
#          '20180125': 5,
#          '20180127': 1,
#          '20180128': 1,
#          '20180129': 4,
#          '20180130': 7,
#          '20180131': 3,
#          '20180201': 5,
#          '20180202': 6,
#          '20180203': 5,
#          '20180204': 6,
#          '20180205': 6,
#          '20180206': 4,
#          '20180207': 3,
#          '20180208': 3,
#          '20180209': 4,
#          '20180210': 5,
#          '20180211': 4,
#          '20180212': 4,
#          '20180213': 2,
#          '20180214': 2,
#          '20180215': 5,
#          '20180216': 1,
#          '20180217': 2,
#          '20180218': 6,
#          '20180219': 3,
#          '20180220': 3,
#          '20180221': 7,
#          '20180222': 5,
#          '20180223': 6,
#          '20180224': 4,
#          '20180225': 7,
#          '20180226': 9,
#          '20180227': 4,
#          '20180228': 5,
#          '20180301': 1,
#          '20180302': 2,
#          '20180303': 4,
#          '20180304': 5,
#          '20180305': 2,
#          '20180306': 5,
#          '20180307': 6,
#          '20180308': 3,
#          '20180309': 2,
#          '20180310': 4,
#          '20180311': 4,
#          '20180312': 2,
#          '20180313': 1,
#          '20180314': 3,
#          '20180315': 4,
#          '20180316': 9,
#          '20180317': 7,
#          '20180318': 8,
#          '20180319': 1,
#          '20180320': 5,
#          '20180321': 3,
#          '20180322': 4,
#          '20180323': 7,
#          '20180324': 3,
#          '20180325': 2,
#          '20180326': 3,
#          '20180327': 4,
#          '20180328': 3,
#          '20180329': 3,
#          '20180330': 3,
#          '20180331': 5,
#          '20180401': 4,
#          '20180402': 3,
#          '20180403': 5,
#          '20180404': 1,
#          '20180405': 7,
#          '20180406': 4,
#          '20180408': 3,
#          '20180409': 6,
#          '20180410': 2,
#          '20180411': 7,
#          '20180412': 10,
#          '20180413': 7,
#          '20180414': 3,
#          '20180415': 14,
#          '20180416': 8,
#          '20180417': 5,
#          '20180418': 4,
#          '20180419': 2,
#          '20180420': 4,
#          '20180421': 8,
#          '20180422': 7,
#          '20180423': 8,
#          '20180424': 7,
#          '20180425': 3,
#          '20180426': 6,
#          '20180427': 6,
#          '20180428': 2,
#          '20180429': 7,
#          '20180430': 3,
#          '20180501': 1,
#          '20180502': 4,
#          '20180503': 6,
#          '20180504': 4,
#          '20180505': 7,
#          '20180507': 2,
#          '20180508': 7,
#          '20180509': 8,
#          '20180510': 8,
#          '20180511': 5,
#          '20180512': 5,
#          '20180513': 7,
#          '20180514': 9,
#          '20180515': 14,
#          '20180516': 7,
#          '20180517': 15,
#          '20180518': 15,
#          '20180519': 9,
#          '20180520': 3,
#          '20180521': 7,
#          '20180522': 6,
#          '20180523': 9,
#          '20180524': 6,
#          '20180525': 7,
#          '20180526': 4,
#          '20180527': 10,
#          '20180528': 10,
#          '20180529': 5,
#          '20180530': 9,
#          '20180531': 7,
#          '20180601': 8,
#          '20180602': 6,
#          '20180603': 4,
#          '20180604': 5,
#          '20180605': 3,
#          '20180606': 6,
#          '20180607': 4,
#          '20180608': 6,
#          '20180609': 5,
#          '20180610': 6,
#          '20180611': 8,
#          '20180612': 11,
#          '20180613': 3,
#          '20180614': 4,
#          '20180615': 1,
#          '20180616': 2,
#          '20180617': 9,
#          '20180618': 9,
#          '20180619': 10,
#          '20180620': 7,
#          '20180621': 8,
#          '20180622': 6,
#          '20180623': 6,
#          '20180624': 9,
#          '20180625': 2})

# %%
freq_table = DataFrame.from_dict(freq_by_acc, orient= 'index').reset_index()
freq_table.columns = ['date', 'count']
freq_table['date'] = [pd.to_datetime(i[:4] + '/' +  i[4:6] + '/' +  i[6:]) for i in freq_table['date']]
freq_table.head()
# Out:
#         date  count
# 0 2018-06-07      4
# 1 2018-06-23      6
# 2 2018-06-24      9
# 3 2018-06-21      8
# 4 2018-06-11      8

# %%
freq_table = DataFrame.from_dict(freq_by_acc, orient= 'index')
freq_table.columns = ['count']
freq_table.index = [pd.to_datetime(i[:4] + '/' +  i[4:6] + '/' +  i[6:]) for i in freq_table.index]
freq_table.head()
# Out:
#             count
# 2018-06-07      4
# 2018-06-23      6
# 2018-06-24      9
# 2018-06-21      8
# 2018-06-11      8

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (16, 8)
freq_table.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Programming\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
