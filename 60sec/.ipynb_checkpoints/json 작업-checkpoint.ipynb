# %%
import pandas as pd

# %%
rd = pd.read_csv('60_56.csv', engine='python')
rd.columns = [i.strip() for i in rd.columns]

# %%
rd
# Out:
#         name  star  salary continent dmg_type range location  dmg  att_speed  \
# 0        아리아     5      20        전체       마법   원거리       공중   21        0.7
# 1         강룡     5      18       아시아       마법   근거리       지상   73        1.1
# 2    알렉스 주니어     5      18       아시아       마법   원거리       지상   75        1.8
# 3       하나카제     5      17       아시아       물리   원거리       지상   70        1.8
# 4       세이메이     5      16       아시아       물리   원거리       공중   47        1.2
# 5         삼장     5      16       아시아       마법   원거리       지상   59        1.4
# 6   노란 눈의 청룡     5      16       아시아       마법   원거리       공중   35        1.0
# 7         관우     5      15       아시아       물리   근거리       지상   29        0.8
# 8        무사시     5      15       아시아       물리   근거리       지상   23        0.7
# 9        인면조     5      15       아시아       물리   원거리       지상   39        1.0
# 10        용왕     5      15       아시아       물리   원거리       지상   54        1.3
# 11       알파고     5      15       아시아       마법   근거리       지상   27        0.8
# 12      저승사자     5      15       아시아       마법   원거리       지상   51        1.3
# 13        시바     5      15       아시아       마법   원거리       지상   43        1.1
# 14       진가령     5      18        유럽       물리   원거리       지상   94        1.3
# 15        발록     5      17        유럽       마법   근거리       지상   56        1.0
# 16    윙드 후사르     5      17        유럽       물리   근거리       지상   29        0.9
# 17     아르테미스     5      16        유럽       물리   원거리       지상   58        1.4
# 18      블랙오딘     5      16        유럽       물리   원거리       공중   33        0.9
# 19     바론 샤드     5      16        유럽       마법   원거리       공중   46        1.2
# 20       악투르     5      15        유럽       물리   근거리       지상   22        0.7
# 21       카르멘     5      15        유럽       물리   원거리       지상   54        1.3
# 22       미디어     5      15        유럽       물리   원거리       지상   34        0.9
# 23    성기사 미치     5      15        유럽       마법   근거리       지상   26        0.8
# 24        사탄     5      15        유럽       마법   원거리       지상   42        1.1
# 25        틱톡     5      15        유럽       마법   원거리       지상   38        1.0
# 26       펄로즈     5      15        유럽       마법   원거리       지상   50        1.2
# 27       소진홍     5      18      아메리카       물리   근거리       지상   80        1.2
# 28      아네모네     5      18      아메리카       마법   원거리       지상  100        1.6
# 29    헌터 크로우     5      17      아메리카       마법   근거리       지상   35        1.0
# ..       ...   ...     ...       ...      ...   ...      ...  ...        ...
# 56    유리 자하드     5      18      아메리카       물리   원거리       지상  127        2.0
# 57  라크 레크레이셔     5      18      아프리카       마법   근거리       지상   48        1.1
# 58        주작     4      12       아시아       물리   원거리       공중   31        0.9
# 59      잔다르크     4      12        유럽       마법   원거리       공중   34        1.0
# 60       베가스     4      12      아메리카       물리   원거리       지상   33        1.0
# 61   미스터 웨스턴     4      12      아메리카       물리   원거리       지상   30        0.9
# 62    브루탈 미니     4      12      아메리카       마법   원거리       공중   29        0.9
# 63    미스터 캡틴     4      12      아메리카       마법   원거리       공중   37        1.1
# 64    샌드 스피릿     4      12      아프리카       마법   원거리       공중   32        1.0
# 65       아주아     4      12      아프리카       마법   원거리       공중   45        1.2
# 66        범수     4      11       아시아       물리   근거리       지상   22        0.8
# 67      세종대왕     4      11       아시아       물리   원거리       지상   48        1.2
# 68        겐조     4      11       아시아       물리   원거리       지상   44        1.2
# 69        밤부     4      11       아시아       마법   근거리       지상   25        0.8
# 70       X보이     4      11       아시아       마법   원거리       지상   35        1.0
# 71       구미호     4      11       아시아       마법   원거리       지상   40        1.1
# 72        셜록     4      11        유럽       물리   근거리       지상   24        0.8
# 73      나폴레옹     4      11        유럽       물리   근거리       지상   28        0.9
# 74        헤라     4      11        유럽       물리   원거리       지상   43        1.2
# 75       베토벤     4      11        유럽       물리   원거리       지상   39        1.1
# 76   알렉산더 대왕     4      11        유럽       마법   근거리       지상   21        0.8
# 77   퀸 엘리자베스     4      11        유럽       마법   원거리       지상   47        1.2
# 78      알브스키     4      11      아메리카       물리   근거리       지상   20        0.7
# 79       앨리스     4      11      아메리카       물리   원거리       지상   42        1.1
# 80       크리스     4      11      아메리카       마법   원거리       지상   46        1.2
# 81       쿠에시     4      11      아프리카       물리   근거리       지상   23        0.8
# 82    찰리 아프칸     4      11      아프리카       물리   원거리       지상   50        1.3
# 83     스콜피온킹     4      11      아프리카       물리   원거리       지상   41        1.1
# 84     이그웨 본     4      11      아프리카       마법   근거리       지상   26        0.8
# 85      머미 잭     4      11      아프리카       마법   원거리       지상   36        1.0
#
#     run_speed     ...       skill1_rate  skill2  skill2_subject  skill2_rate  \
# 0         0.7     ...              0.34      공속              전체         0.05
# 1         1.9     ...              1.63     공격력             근거리         0.81
# 2         1.7     ...              0.05     공격력              자신         0.80
# 3         1.0     ...              0.05      이속              전체         0.05
# 4         0.9     ...              0.56      치확             원거리         0.08
# 5         0.7     ...              0.78      이속              전체         0.05
# 6         1.2     ...              4.95      치확             아시아         0.07
# 7         1.3     ...              1.11     공격력              자신         1.11
# 8         1.4     ...              3.00      물리              자신         0.78
# 9         1.1     ...              1.68      치피             원거리         6.72
# 10        0.8     ...              1.11      치확              전체         0.05
# 11        1.3     ...              0.80     공격력              자신         0.78
# 12        0.8     ...              0.82      이속             원거리         0.08
# 13        1.0     ...              3.72      이속             원거리         0.08
# 14        1.7     ...              0.64      공속              유럽         0.08
# 15        1.8     ...              0.10      체력              유럽         0.83
# 16        1.9     ...              1.73      체력             근거리         0.84
# 17        0.7     ...              2.34      공속              자신         0.10
# 18        1.2     ...              1.34      공속             원거리         0.08
# 19        1.0     ...              1.00      공속              자신         0.10
# 20        1.4     ...              2.06     공격력              자신         2.06
# 21        0.8     ...              1.46      치확              전체         0.05
# 22        1.2     ...              1.11      공속              자신         0.10
# 23        1.3     ...              1.74      이속              유럽         0.07
# 24        1.0     ...              3.93      이속             원거리         0.08
# 25        1.1     ...              1.23      치피              자신         5.04
# 26        0.9     ...              2.67      이속             원거리         0.08
# 27        1.8     ...              1.80     공격력              자신         0.88
# 28        1.4     ...              0.10     공격력            아메리카         0.52
# 29        1.8     ...              1.31      치확            아메리카         0.08
# ..        ...     ...               ...     ...             ...          ...
# 56        1.2     ...              2.08      공속            아메리카         0.07
# 57        2.1     ...              1.08      마방            아프리카         0.07
# 58        1.1     ...              0.32      공속             원거리         0.06
# 59        1.0     ...              0.93      치확              자신         0.08
# 60        1.0     ...              2.22      치피              자신         8.88
# 61        1.1     ...              0.70      공속             원거리         0.06
# 62        1.1     ...              1.02      치피              전체         3.92
# 63        1.0     ...              0.47      공속              자신         0.08
# 64        1.1     ...              0.36      치확            아프리카         0.05
# 65        0.8     ...              0.43      치확              전체         0.04
# 66        1.2     ...              0.44     공격력              전체         0.44
# 67        0.8     ...              0.61      이속              전체         0.04
# 68        0.8     ...              1.19      물방              자신         0.08
# 69        1.2     ...              1.26     공격력              자신         1.25
# 70        1.0     ...              0.71      치확              전체         0.04
# 71        0.9     ...              0.75      이속             원거리         0.06
# 72        1.2     ...              0.48     공격력              자신         0.50
# 73        1.1     ...              0.44     공격력              자신         0.49
# 74        0.8     ...              0.34      치확              유럽         0.05
# 75        0.9     ...              0.47      공속              자신         0.08
# 76        1.2     ...              0.05     공격력              자신         3.36
# 77        0.8     ...              1.00      이속              전체         0.04
# 78        1.3     ...              1.22     공격력              자신         1.23
# 79        0.9     ...              0.34      치확              전체         0.04
# 80        0.8     ...              0.79      공속             원거리         0.06
# 81        1.2     ...              0.05     공격력             근거리         1.23
# 82        0.7     ...              1.75      공속            아프리카         0.05
# 83        0.9     ...              0.54      이속             원거리         0.06
# 84        1.2     ...              0.73     공격력              자신         0.75
# 85        1.0     ...              0.55      치확              전체         0.04
#
#     skill3  skill3_subject  skill3_rate skill4 skill4_subject  skill4_rate
# 0       치피              전체         1.28     체력             전체         0.33
# 1       체력             아시아         0.81     마방             자신         0.10
# 2       공속              전체         0.05     체력             전체         0.25
# 3       치피             아시아         1.30     체력            원거리         0.35
# 4       체력              전체         0.50     회피             자신         0.02
# 5       치확              자신         0.10     치피             전체         3.12
# 6       물방             아시아         0.07     회피             전체         0.05
# 7       회피             아시아         0.07     이속            아시아         0.07
# 8       체력             아시아         0.75     물방            근거리         0.08
# 9       물방             아시아         0.07     회피            아시아         0.07
# 10      치피             원거리         4.36     물방            원거리         0.08
# 11      회피             근거리         0.08     공속             자신         0.10
# 12      치피              전체         3.20     회피             전체         0.05
# 13      마방              전체         0.05     회피             자신         0.10
# 14      이속              전체         0.05     체력            원거리         0.64
# 15      회피             근거리         0.07    공격력             전체         0.83
# 16      물방              자신         0.10     회피             유럽         0.08
# 17      이속              전체         0.05     치확             유럽         0.07
# 18      마방              자신         0.10     회피             자신         0.10
# 19      체력              자신         1.00     물방             자신         0.10
# 20      물방              자신         0.10     마방            근거리         0.08
# 21      체력              자신         1.46     물방            원거리         0.08
# 22      치확              유럽         0.07     마방             자신         0.10
# 23      체력              자신         1.74     마방            근거리         0.08
# 24      물방              자신         0.10     회피             유럽         0.07
# 25      물방              전체         0.05     마방            원거리         0.08
# 26      치확              유럽         0.07     회피             유럽         0.07
# 27      체력             근거리         0.87     회피             전체         0.05
# 28      이속             원거리         0.07     체력             전체         0.49
# 29      체력             근거리         0.62     회피             전체         0.05
# ..     ...             ...          ...    ...            ...          ...
# 56      치피             원거리         2.08     이속             전체         0.05
# 57      물방             근거리         0.08    공격력             전체         1.08
# 58      치확             아시아         0.05     체력             자신         0.33
# 59      물방             원거리         0.06     회피             자신         0.08
# 60      마방             원거리         0.06     회피             전체         0.04
# 61      치확              전체         0.04     물방            원거리         0.06
# 62      마방            아메리카         0.05     회피             자신         0.08
# 63      이속             원거리         0.06     치피             전체         1.76
# 64      치피            아프리카         1.44     체력             전체         0.35
# 65      치피             원거리         1.68     마방            원거리         0.06
# 66      물방              자신         0.08     치피            아시아         1.72
# 67      치피              자신         2.44     체력            아시아         0.59
# 68      마방              자신         0.08     회피             자신         0.08
# 69      마방              전체         0.04     이속            아시아         0.05
# 70      마방              전체         0.04     회피             자신         0.08
# 71      치확              자신         0.08     체력             자신         0.74
# 72      마방              자신         0.08     치피             전체         1.88
# 73      물방              자신         0.08     이속             유럽         0.05
# 74      체력              전체         0.33     물방             자신         0.08
# 75      이속             원거리         0.06     체력             유럽         0.44
# 76      마방             근거리         0.06     치확             유럽         0.05
# 77      치피              유럽         4.00     물방            원거리         0.06
# 78      물방             근거리         0.06     이속           아메리카         0.05
# 79      체력             원거리         0.33     마방             자신         0.08
# 80      이속              전체         0.04     회피             전체         0.04
# 81      회피              자신         0.08     치피             자신         5.00
# 82      이속              전체         0.04     물방            원거리         0.06
# 83      치피              자신         2.12     체력           아프리카         0.53
# 84      마방             근거리         0.06     이속           아프리카         0.05
# 85      치피              전체         2.16     물방           아프리카         0.05
#
# [86 rows x 29 columns]

# %%
rd.shape
# Out:
# (86, 29)

# %%
tmp = rd.loc[:,['star', 'salary', 'dmg', 'hp', 'att_range']]
for r in range(tmp.shape[0]):
    for c in range(tmp.shape[1]):
        tmp.iloc[r,c]= int(tmp.iloc[r,c])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
# star         86 non-null int32
# salary       86 non-null int32
# dmg          86 non-null int32
# hp           86 non-null int32
# att_range    86 non-null int32
# dtypes: int32(5)
# memory usage: 1.8 KB

# %%
rd.loc[:,['star', 'salary', 'dmg', 'hp', 'att_range']] = tmp

# %%
tmp = rd.loc[:, ['att_speed', 'run_speed', 'crit_rate', 'crit_dmg', 'phy_def', 'mag_def', 'evasion', 'skill1_rate', 'skill2_rate', 'skill3_rate']]
for r in range(tmp.shape[0]):
    for c in range(tmp.shape[1]):
        tmp.iloc[r,c]= int(tmp.iloc[r,c])
        
rd.loc[:, ['att_speed', 'run_speed', 'crit_rate', 'crit_dmg', 'phy_def', 'mag_def', 'evasion', 'skill1_rate', 'skill2_rate', 'skill3_rate']]= tmp

# %%
import json

# %%
tmp = dict(rd.iloc[0,:7])
tmp['stats'] = dict(rd.iloc[0,7:17])
tmp['skills'] = dict(rd.iloc[0,17:])

# %%
tmp
# Out:
# {'name': '아리아',
#  'star': 5,
#  'salary': 20,
#  'continent': '전체',
#  'dmg_type': '마법',
#  'range': '원거리',
#  'location': '공중',
#  'stats': {'dmg': 21,
#   'att_speed': 0.0,
#   'run_speed': 0.0,
#   'crit_rate': 10.0,
#   'crit_dmg': 150.0,
#   'hp': 102,
#   'phy_def': 1.0,
#   'mag_def': 3.0,
#   'evasion': 1.0,
#   'att_range': 200},
#  'skills': {'skill1': '공격력',
#   'skill1_subject': '전체',
#   'skill1_rate': 0.0,
#   'skill2': '공속',
#   'skill2_subject': '전체',
#   'skill2_rate': 0.0,
#   'skill3': '치피',
#   'skill3_subject': '전체',
#   'skill3_rate': 1.0,
#   'skill4': '체력',
#   'skill4_subject': '전체',
#   'skill4_rate': 0.33}}

# %%
knights = []

for i in range(len(rd)):
    tmp = dict(rd.iloc[i, :7])
    tmp['stats'] = dict(rd.iloc[i, 7:17])
    tmp['skills'] = dict(rd.iloc[i, 17:])
    knights.append(tmp)

# %%
knights = {'knights': knights}

# %%
type(knights['knights'][0]['star'])
# Out:
# numpy.int32

# %%
for knight in knights['knights']:
    knight['star'] = int(knight['star'])
    knight['salary'] = int(knight['salary'])
    knight['stats']['dmg'] = int(knight['stats']['dmg'])
    knight['stats']['att_speed'] = float(knight['stats']['att_speed'])
    knight['stats']['run_speed'] = float(knight['stats']['run_speed'])
    knight['stats']['crit_rate'] = float(knight['stats']['crit_rate'])
    knight['stats']['crit_dmg'] = float(knight['stats']['crit_dmg'])
    knight['stats']['hp'] = int(knight['stats']['hp'])
    knight['stats']['phy_def'] = float(knight['stats']['phy_def'])
    knight['stats']['mag_def'] = float(knight['stats']['mag_def'])
    knight['stats']['evasion'] = float(knight['stats']['evasion'])
    knight['stats']['att_range'] = int(knight['stats']['att_range'])
    knight['skills']['skill1_rate'] = float(knight['skills']['skill1_rate'])
    knight['skills']['skill2_rate'] = float(knight['skills']['skill2_rate'])
    knight['skills']['skill3_rate'] = float(knight['skills']['skill3_rate'])

# %%
a = json.dumps(knights, ensure_ascii=False)

# %%
with open('char.json', 'w', encoding = 'utf-8') as f:
    f.write(a)
    f.close()
